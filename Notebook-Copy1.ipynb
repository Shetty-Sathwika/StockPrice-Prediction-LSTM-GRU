# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import json
import re
import os
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, roc_auc_score

# %%
import tensorflow as tf
import transformers
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.optimizers import Adam
from keras.utils.vis_utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
#importing libraries for model evaluation and algorithms
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import collections
import nltk
from sklearn import preprocessing
from nltk.tokenize import sent_tokenize, word_tokenize
# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder
#dl libraraies
import keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization,Reshape,Dot,Concatenate,Add,Lambda
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau
#import cv2
from tensorflow.keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
import os
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import LSTM, GRU
from tensorflow.keras.preprocessing.sequence import pad_sequences
# specifically for deeplearning.
from tensorflow.keras.layers import Dropout, Flatten,Activation,Input,Embedding
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from kerastuner import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import layers, callbacks
from tensorflow.keras import Model, Sequential

from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
import re
import string

# %% [markdown]
# # Sentiment

# %%
df_train = pd.read_csv('data/stock_data.csv')
df_val = pd.read_csv('data/stock_data.csv')
df_test = pd.read_csv('data/stock_data.csv')

# %%
print(df_train.info())
df_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5791 entries, 0 to 5790
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       5791 non-null   object
#  1   Sentiment  5791 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 90.6+ KB
# None
#                                                 Text  Sentiment
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1  user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2  user I'd be afraid to short AMZN - they are lo...          1
# 3                                  MNTA Over 12.00            1
# 4                                   OI  Over 21.37            1

# %%
import seaborn as sns
sns.countplot(x="Sentiment", data = df_train)
# Out:
# <Axes: xlabel='Sentiment', ylabel='count'>

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
comment_words = ''
stopwords = set(STOPWORDS)

# %%
for val in df_train.Text:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)

# plot the WordCloud image                      
plt.figure(figsize = (12, 12), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize
import string 
from nltk.stem import WordNetLemmatizer

# %%
Tweet = []
Labels = []

for row in df_train["Text"]:
    #tokenize words
    words = word_tokenize(row)
    #remove punctuations
    clean_words = [word.lower() for word in words if word not in set(string.punctuation)]
    #remove stop words
    english_stops = set(stopwords.words('english'))
    characters_to_remove = ["''",'``',"rt","https","’","“","”","\u200b","--","n't","'s","...","//t.c" ]
    clean_words = [word for word in clean_words if word not in english_stops]
    clean_words = [word for word in clean_words if word not in set(characters_to_remove)]
    #Lematise words
    wordnet_lemmatizer = WordNetLemmatizer()
    lemma_list = [wordnet_lemmatizer.lemmatize(word) for word in clean_words]
    Tweet.append(lemma_list)

# %%
X = df_train['Text']
y = df_train['Sentiment']

# %%
# Extract Feature With CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(X) # Fit the Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
ML_Model = []
accuracy = []
precision = []
recall = []
f1score = []

#function to call for storing the results
def storeResults(model, a,b,c,d):
    ML_Model.append(model)
    accuracy.append(round(a, 3))
    precision.append(round(d, 3))
    recall.append(round(c, 3))
    f1score.append(round(b, 3))

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(random_state=1, max_iter=300)
mlp.fit(X_train, y_train) 
y_pred = mlp.predict(X_test)

mlp_acc = accuracy_score(y_test, y_pred)
mlp_prec = precision_score(y_test, y_pred,average='weighted')
mlp_rec = recall_score(y_test, y_pred,average='weighted')
mlp_f1 = f1_score(y_test, y_pred,average='weighted')

# %%
storeResults('MLP',mlp_acc,mlp_prec,mlp_rec,mlp_f1)

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

y_train = y_train.replace(-1, 0)
y_test = y_test.replace(-1, 0)

# Train model
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb.fit(X_train, y_train)

# Predict
y_pred = xgb.predict(X_test)

xgb_acc = accuracy_score(y_test, y_pred)
xgb_prec = precision_score(y_test, y_pred,average='weighted')
xgb_rec = recall_score(y_test, y_pred,average='weighted')
xgb_f1 = f1_score(y_test, y_pred,average='weighted')

# %%
storeResults('XGBoost',xgb_acc,xgb_prec,xgb_rec,xgb_f1)

# %% [markdown]
# # Voting Classifier

# %%
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, AdaBoostClassifier
clf1 = AdaBoostClassifier(n_estimators=100, random_state=0)
clf2 = RandomForestClassifier(n_estimators=50, random_state=1)

eclf1 = VotingClassifier(estimators=[('ad', clf1), ('rf', clf2)], voting='soft')
eclf1.fit(X_train, y_train)
y_pred = eclf1.predict(X_test)

vot_acc = accuracy_score(y_pred, y_test)
vot_prec = precision_score(y_pred, y_test,average='weighted')
vot_rec = recall_score(y_pred, y_test,average='weighted')
vot_f1 = f1_score(y_pred, y_test,average='weighted')

# %%
storeResults('Voting CLassifier',vot_acc,vot_prec,vot_rec,vot_f1)

# %% [markdown]
# DL

# %%
#reading the dataframe
data=pd.read_csv('data/stock_data.csv')
data.head()
# Out:
#                                                 Text  Sentiment
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1  user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2  user I'd be afraid to short AMZN - they are lo...          1
# 3                                  MNTA Over 12.00            1
# 4                                   OI  Over 21.37            1

# %%
# changing attack labels to their respective attack class
def change_label(df):
  df.Sentiment.replace([-1],0,inplace=True)

# %%
change_label(data)

# %%
sns.countplot(x="Sentiment", data = data)

# %%
#Setting parameters which will be used throughout
num_words = 15000  # Parameter indicating the number of words we'll put in the dictionary
val_size = 100  # Size of the validation set
epochs = 20  # Number of epochs we usually start to train with
batch_size = 8  # Size of the batches used in the mini-batch gradient descent
#Taking only two columns since it's a sentiment analysis

# %%
num_classes = data.Sentiment.nunique()
print(num_classes)
# Out:
# 2

# %%
def cleaning_text(text):
    stop_words = stopwords.words("english")

    text = re.sub(r'http\S+', " ", text)    # remove urls
    text = re.sub(r'@\w+',' ',text)         # remove mentions
    text = re.sub(r'#\w+', ' ', text)       # remove hastags
    text = re.sub('r<.*?>',' ', text)       # remove html tags
    
    # remove stopwords 
    text = text.split()
    text = " ".join([word for word in text if not word in stop_words])

    for punctuation in string.punctuation:
        text = text.replace(punctuation, "")
    
    return text

# %%
data['text'] = data['Text'].apply(lambda x: cleaning_text(x))

# %%
# Maximum sentence length
max_len_words = max(list(data['text'].apply(len)))
print(max_len_words)
# Out:
# 126

# %%
def tokenizer(x_train, y_train, max_len_word):
    # because the data distribution is imbalanced, "stratify" is used
    X_train, X_val, y_train, y_val = train_test_split(x_train, y_train, 
                                                      test_size=.2, shuffle=True, 
                                                      stratify=y_train, random_state=0)

    # Tokenizer
    tokenizer = Tokenizer(num_words=5000)
    tokenizer.fit_on_texts(X_train)
    sequence_dict = tokenizer.word_index
    word_dict = dict((num, val) for (val, num) in sequence_dict.items())

    # Sequence data
    train_sequences = tokenizer.texts_to_sequences(X_train)
    train_padded = pad_sequences(train_sequences,
                                 maxlen=max_len_word,
                                 truncating='post',
                                 padding='post')
    
    val_sequences = tokenizer.texts_to_sequences(X_val)
    val_padded = pad_sequences(val_sequences,
                                maxlen=max_len_word,
                                truncating='post',
                                padding='post', )
    
    print(train_padded.shape)
    print(val_padded.shape)
    print('Total words: {}'.format(len(word_dict)))
    return train_padded, val_padded, y_train, y_val, word_dict

X_train, X_val, y_train, y_val, word_dict = tokenizer(data.Text, data.Sentiment, 100)
# Out:
# (4632, 100)
# (1159, 100)
# Total words: 8980

# %% [markdown]
# # CNN

# %%
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam, SGD
def build_cnn_model():
    model = Sequential()
    
    model.add(Embedding(5000, 100, input_length=100))


    model.add(Conv1D(64, 2, padding='same', activation='relu'))
    model.add(MaxPooling1D(2))
    #model.add(MaxPooling1D(2))
    
    model.add(Flatten())
    
    model.add(Dense(units=1024,activation="relu"))
    model.add(Dense(units=512,activation="relu"))
    
    model.add(Dense(units=num_classes,activation="softmax"))
    
    optimizer = Adam(lr=0.000055,beta_1=0.9,beta_2=0.999)
    
    model.compile(optimizer=optimizer,metrics=["accuracy"],loss=tf.keras.losses.SparseCategoricalCrossentropy())
    return model

# %%
cnn_model = build_cnn_model()

# %%
history = cnn_model.fit(X_train, y_train,
                    epochs=20, 
                    validation_data=(X_val, y_val),
                    shuffle=True)
# Out:
# Epoch 1/20
# 145/145 [==============================] - 5s 29ms/step - loss: 0.6556 - accuracy: 0.6360 - val_loss: 0.6540 - val_accuracy: 0.6368
# Epoch 2/20
# 145/145 [==============================] - 5s 31ms/step - loss: 0.6474 - accuracy: 0.6362 - val_loss: 0.6456 - val_accuracy: 0.6368
# Epoch 3/20
# 145/145 [==============================] - 6s 40ms/step - loss: 0.6079 - accuracy: 0.6608 - val_loss: 0.5915 - val_accuracy: 0.6557
# Epoch 4/20
# 145/145 [==============================] - 6s 39ms/step - loss: 0.4494 - accuracy: 0.7923 - val_loss: 0.4940 - val_accuracy: 0.7524
# Epoch 5/20
# 145/145 [==============================] - 6s 39ms/step - loss: 0.2837 - accuracy: 0.8912 - val_loss: 0.4869 - val_accuracy: 0.7886
# Epoch 6/20
# 145/145 [==============================] - 6s 38ms/step - loss: 0.1769 - accuracy: 0.9411 - val_loss: 0.5331 - val_accuracy: 0.7886
# Epoch 7/20
# 145/145 [==============================] - 6s 38ms/step - loss: 0.1093 - accuracy: 0.9668 - val_loss: 0.5526 - val_accuracy: 0.7826
# Epoch 8/20
# 145/145 [==============================] - 6s 38ms/step - loss: 0.0678 - accuracy: 0.9838 - val_loss: 0.6018 - val_accuracy: 0.7869
# Epoch 9/20
# 145/145 [==============================] - 6s 38ms/step - loss: 0.0411 - accuracy: 0.9935 - val_loss: 0.6758 - val_accuracy: 0.7817
# Epoch 10/20
# 145/145 [==============================] - 6s 38ms/step - loss: 0.0266 - accuracy: 0.9957 - val_loss: 0.7275 - val_accuracy: 0.7817
# Epoch 11/20
# 145/145 [==============================] - 6s 39ms/step - loss: 0.0169 - accuracy: 0.9978 - val_loss: 0.7789 - val_accuracy: 0.7817
# Epoch 12/20
# 145/145 [==============================] - 6s 38ms/step - loss: 0.0120 - accuracy: 0.9991 - val_loss: 0.7877 - val_accuracy: 0.7834
# Epoch 13/20
# 145/145 [==============================] - 6s 39ms/step - loss: 0.0090 - accuracy: 0.9991 - val_loss: 0.8243 - val_accuracy: 0.7869
# Epoch 14/20
# 145/145 [==============================] - 6s 38ms/step - loss: 0.0070 - accuracy: 0.9994 - val_loss: 0.8771 - val_accuracy: 0.7860
# Epoch 15/20
# 145/145 [==============================] - 6s 39ms/step - loss: 0.0053 - accuracy: 0.9994 - val_loss: 0.9221 - val_accuracy: 0.7869
# Epoch 16/20
# 145/145 [==============================] - 6s 38ms/step - loss: 0.0043 - accuracy: 0.9996 - val_loss: 0.9374 - val_accuracy: 0.7852
# Epoch 17/20
# 145/145 [==============================] - 6s 39ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.9584 - val_accuracy: 0.7843
# Epoch 18/20
# 145/145 [==============================] - 6s 38ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 1.0233 - val_accuracy: 0.7860
# Epoch 19/20
# 145/145 [==============================] - 6s 39ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 1.0007 - val_accuracy: 0.7895
# Epoch 20/20
# 145/145 [==============================] - 6s 39ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 1.1694 - val_accuracy: 0.7731

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy Curves')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Curves')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_pred = cnn_model.predict(X_val, batch_size=16)
y_pred = np.argmax(y_pred,axis=1)

cnn_acc = accuracy_score(y_val, y_pred)
cnn_prec = precision_score(y_val, y_pred,average='weighted')
cnn_rec = recall_score(y_val, y_pred,average='weighted')
cnn_f1 = f1_score(y_val, y_pred,average='weighted')

# %%
storeResults('CNN',cnn_acc,cnn_prec,cnn_rec,cnn_f1)

# %% [markdown]
# # LSTM

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from kerastuner import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters

# %%
#tweets conssits of every document as an array of tokenized words which are later appended to docs 
tweets=[word_tokenize(tweet) for tweet in data['Text']]
docs=[]
for j in range(0,len(tweets)):
    docs.append(tweets[j])

# %%
#stops included both the stopwords and punctuations
from nltk.corpus import stopwords
import string
stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
not_list = ["n't", "not", "no"]
stops.update(punctuations)
stops.update(not_list)

#to get the simple pos(part of speech) tag
from nltk.corpus import wordnet
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
#to get the pos tag for a word
from nltk import pos_tag
# now we are going to clean our data 
# we will remove stopwords and punctuations and lemmatize each document
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
def clean(words):
    output=[]
    for word in words:
        if word.lower() not in stops or word.lower() in not_list:
            pos=pos_tag(word)
            clean_word=lemmatizer.lemmatize(word,pos=get_simple_pos(pos[0][1]))
            output.append(clean_word.lower())
    str1=" ".join(output).encode('utf-8')        
    return str1
#docs=[ clean(doc) for doc in docs]

# %%
#taking variables to be used for train test split as X,y
X,Y=data['Text'].values,pd.get_dummies(data.Sentiment.values)

# %%
#using tokenizers to create the tokens having no of words=15000(num_words)
tk = Tokenizer(num_words=num_words,
               filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
               lower=True,
               split=" ")
#Complete data is tokenized to vectors and padding is done using zeros to match its length to the largest text in the dataset.
tk.fit_on_texts(X)
X = tk.texts_to_sequences(X)
X = pad_sequences(X)
#print(X[:2])
print('Fitted tokenizer on {} documents'.format(tk.document_count))
print('{} words in dictionary'.format(tk.num_words))
print('Top 5 most common words are:', collections.Counter(tk.word_counts).most_common(5))
# Out:
# Fitted tokenizer on 5791 documents
# 15000 words in dictionary
# Top 5 most common words are: [('the', 1992), ('to', 1816), ('a', 1386), ('on', 1098), ('in', 1032)]

# %%
import pickle
pickle.dump(tk,open('transform.pkl','wb'))

# %%
#train test split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)
print('# Train data samples:', X_train.shape)
print('# Test data samples:', X_test.shape)
# Out:
# # Train data samples: (4632, 34)
# # Test data samples: (1159, 34)

# %%
#Function defined to test the models in the test set
def test_model(model, epoch_stop):
    model.fit(X_train, Y_train
              , epochs=epoch_stop
              , batch_size=batch_size
              , verbose=0)
    results = model.evaluate(X_train, Y_train)
    
    return results

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
embed_dim = 128 #dimension of the word embedding vector for each word in a sequence 
lstm_out = 196  #no of lstm layers
lstm_model = Sequential()
lstm_model.add(Embedding(num_words, embed_dim,input_length = X_train.shape[1]))
#Adding dropout
lstm_model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
#Adding a regularized dense layer
lstm_model.add(layers.Dense(32,kernel_regularizer=regularizers.l2(0.001),activation='relu'))
lstm_model.add(layers.Dropout(0.5))
lstm_model.add(Dense(2,activation='softmax'))
lstm_model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy',f1_m,recall_m,precision_m])
#print(lstm_model.summary())

# %%
#model trained on the training data and taking validation data into account to avoid overfitting for 4 epochs 
history_LSTM=lstm_model.fit(X_train, Y_train, epochs = 20, batch_size=batch_size,validation_data=(X_test, Y_test),verbose = 1)
# Out:
# Epoch 1/20
# 579/579 [==============================] - 58s 97ms/step - loss: 0.5979 - accuracy: 0.6978 - f1_m: 0.6978 - recall_m: 0.6978 - precision_m: 0.6978 - val_loss: 0.3580 - val_accuracy: 0.8661 - val_f1_m: 0.8661 - val_recall_m: 0.8661 - val_precision_m: 0.8661
# Epoch 2/20
# 579/579 [==============================] - 57s 98ms/step - loss: 0.3569 - accuracy: 0.8683 - f1_m: 0.8683 - recall_m: 0.8683 - precision_m: 0.8683 - val_loss: 0.1559 - val_accuracy: 0.9573 - val_f1_m: 0.9573 - val_recall_m: 0.9573 - val_precision_m: 0.9573
# Epoch 3/20
# 579/579 [==============================] - 56s 96ms/step - loss: 0.1902 - accuracy: 0.9387 - f1_m: 0.9387 - recall_m: 0.9387 - precision_m: 0.9387 - val_loss: 0.0878 - val_accuracy: 0.9814 - val_f1_m: 0.9814 - val_recall_m: 0.9814 - val_precision_m: 0.9814
# Epoch 4/20
# 579/579 [==============================] - 56s 96ms/step - loss: 0.0909 - accuracy: 0.9737 - f1_m: 0.9737 - recall_m: 0.9737 - precision_m: 0.9737 - val_loss: 0.0376 - val_accuracy: 0.9927 - val_f1_m: 0.9927 - val_recall_m: 0.9927 - val_precision_m: 0.9927
# Epoch 5/20
# 579/579 [==============================] - 54s 94ms/step - loss: 0.0623 - accuracy: 0.9834 - f1_m: 0.9834 - recall_m: 0.9834 - precision_m: 0.9834 - val_loss: 0.0263 - val_accuracy: 0.9959 - val_f1_m: 0.9959 - val_recall_m: 0.9959 - val_precision_m: 0.9959
# Epoch 6/20
# 579/579 [==============================] - 54s 94ms/step - loss: 0.0395 - accuracy: 0.9918 - f1_m: 0.9918 - recall_m: 0.9918 - precision_m: 0.9918 - val_loss: 0.0132 - val_accuracy: 0.9985 - val_f1_m: 0.9985 - val_recall_m: 0.9985 - val_precision_m: 0.9985
# Epoch 7/20
# 579/579 [==============================] - 54s 93ms/step - loss: 0.0204 - accuracy: 0.9976 - f1_m: 0.9976 - recall_m: 0.9976 - precision_m: 0.9976 - val_loss: 0.0120 - val_accuracy: 0.9981 - val_f1_m: 0.9981 - val_recall_m: 0.9981 - val_precision_m: 0.9981
# Epoch 8/20
# 579/579 [==============================] - 54s 94ms/step - loss: 0.0290 - accuracy: 0.9940 - f1_m: 0.9940 - recall_m: 0.9940 - precision_m: 0.9940 - val_loss: 0.0181 - val_accuracy: 0.9963 - val_f1_m: 0.9963 - val_recall_m: 0.9963 - val_precision_m: 0.9963
# Epoch 9/20
# 579/579 [==============================] - 53s 92ms/step - loss: 0.0278 - accuracy: 0.9942 - f1_m: 0.9942 - recall_m: 0.9942 - precision_m: 0.9942 - val_loss: 0.0148 - val_accuracy: 0.9974 - val_f1_m: 0.9974 - val_recall_m: 0.9974 - val_precision_m: 0.9974
# Epoch 10/20
# 579/579 [==============================] - 53s 91ms/step - loss: 0.0202 - accuracy: 0.9965 - f1_m: 0.9965 - recall_m: 0.9965 - precision_m: 0.9965 - val_loss: 0.0090 - val_accuracy: 0.9994 - val_f1_m: 0.9994 - val_recall_m: 0.9994 - val_precision_m: 0.9994
# Epoch 11/20
# 579/579 [==============================] - 53s 92ms/step - loss: 0.0204 - accuracy: 0.9955 - f1_m: 0.9955 - recall_m: 0.9955 - precision_m: 0.9955 - val_loss: 0.0150 - val_accuracy: 0.9961 - val_f1_m: 0.9961 - val_recall_m: 0.9961 - val_precision_m: 0.9961
# Epoch 12/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0184 - accuracy: 0.9963 - f1_m: 0.9963 - recall_m: 0.9963 - precision_m: 0.9963 - val_loss: 0.0167 - val_accuracy: 0.9965 - val_f1_m: 0.9965 - val_recall_m: 0.9965 - val_precision_m: 0.9965
# Epoch 13/20
# 579/579 [==============================] - 51s 89ms/step - loss: 0.0112 - accuracy: 0.9981 - f1_m: 0.9981 - recall_m: 0.9981 - precision_m: 0.9981 - val_loss: 0.0048 - val_accuracy: 0.9998 - val_f1_m: 0.9998 - val_recall_m: 0.9998 - val_precision_m: 0.9998
# Epoch 14/20
# 579/579 [==============================] - 51s 89ms/step - loss: 0.0061 - accuracy: 0.9996 - f1_m: 0.9996 - recall_m: 0.9996 - precision_m: 0.9996 - val_loss: 0.0031 - val_accuracy: 1.0000 - val_f1_m: 1.0000 - val_recall_m: 1.0000 - val_precision_m: 1.0000
# Epoch 15/20
# 579/579 [==============================] - 51s 88ms/step - loss: 0.0107 - accuracy: 0.9987 - f1_m: 0.9987 - recall_m: 0.9987 - precision_m: 0.9987 - val_loss: 0.0065 - val_accuracy: 0.9987 - val_f1_m: 0.9987 - val_recall_m: 0.9987 - val_precision_m: 0.9987
# Epoch 16/20
# 579/579 [==============================] - 52s 89ms/step - loss: 0.0145 - accuracy: 0.9963 - f1_m: 0.9963 - recall_m: 0.9963 - precision_m: 0.9963 - val_loss: 0.0063 - val_accuracy: 0.9989 - val_f1_m: 0.9989 - val_recall_m: 0.9989 - val_precision_m: 0.9989
# Epoch 17/20
# 579/579 [==============================] - 54s 94ms/step - loss: 0.0100 - accuracy: 0.9985 - f1_m: 0.9985 - recall_m: 0.9985 - precision_m: 0.9985 - val_loss: 0.0129 - val_accuracy: 0.9959 - val_f1_m: 0.9959 - val_recall_m: 0.9959 - val_precision_m: 0.9959
# Epoch 18/20
# 579/579 [==============================] - 51s 88ms/step - loss: 0.0081 - accuracy: 0.9989 - f1_m: 0.9989 - recall_m: 0.9989 - precision_m: 0.9989 - val_loss: 0.0047 - val_accuracy: 0.9996 - val_f1_m: 0.9996 - val_recall_m: 0.9996 - val_precision_m: 0.9996
# Epoch 19/20
# 579/579 [==============================] - 51s 87ms/step - loss: 0.0084 - accuracy: 0.9989 - f1_m: 0.9989 - recall_m: 0.9989 - precision_m: 0.9989 - val_loss: 0.0042 - val_accuracy: 0.9996 - val_f1_m: 0.9996 - val_recall_m: 0.9996 - val_precision_m: 0.9996
# Epoch 20/20
# 579/579 [==============================] - 51s 88ms/step - loss: 0.0059 - accuracy: 0.9994 - f1_m: 0.9994 - recall_m: 0.9994 - precision_m: 0.9994 - val_loss: 0.0026 - val_accuracy: 0.9998 - val_f1_m: 0.9998 - val_recall_m: 0.9998 - val_precision_m: 0.9998

# %%
import matplotlib.pyplot as plt

x=history_LSTM
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(x.history['loss'], label='Training Loss')
plt.plot(x.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(x.history['accuracy'], label='Training Accuracy')
plt.plot(x.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
lstm_acc = history_LSTM.history['val_accuracy'][19]
lstm_prec = history_LSTM.history['val_precision_m'][19]
lstm_rec = history_LSTM.history['val_recall_m'][19]
lstm_f1 = history_LSTM.history['val_f1_m'][19]

# %%
storeResults('LSTM',lstm_acc,lstm_prec,lstm_rec,lstm_f1)

# %% [markdown]
# # MS-LSTM

# %%
embed_dim = 128 #dimension of the word embedding vector for each word in a sequence 
lstm_out = 196  #no of lstm layers
lstm_model = Sequential()
lstm_model.add(Embedding(num_words, embed_dim,input_length = X_train.shape[1]))
#Adding dropout
lstm_model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
#Adding a regularized dense layer
lstm_model.add(layers.Dense(128,kernel_regularizer=regularizers.l2(0.001),activation='relu'))
lstm_model.add(layers.Dropout(0.5))

lstm_model.add(Dense(2,activation='softmax'))
lstm_model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy',f1_m,recall_m,precision_m])
#print(lstm_model.summary())

# %%
#model trained on the training data and taking validation data into account to avoid overfitting for 4 epochs 
history_LSTM=lstm_model.fit(X_train, Y_train, epochs = 20, batch_size=batch_size,validation_data=(X_test, Y_test),verbose = 1)
# Out:
# Epoch 1/20
# 579/579 [==============================] - 52s 87ms/step - loss: 0.6006 - accuracy: 0.7081 - f1_m: 0.7081 - recall_m: 0.7081 - precision_m: 0.7081 - val_loss: 0.4262 - val_accuracy: 0.8638 - val_f1_m: 0.8638 - val_recall_m: 0.8638 - val_precision_m: 0.8638
# Epoch 2/20
# 579/579 [==============================] - 50s 87ms/step - loss: 0.3278 - accuracy: 0.8735 - f1_m: 0.8735 - recall_m: 0.8735 - precision_m: 0.8735 - val_loss: 0.1531 - val_accuracy: 0.9614 - val_f1_m: 0.9614 - val_recall_m: 0.9614 - val_precision_m: 0.9614
# Epoch 3/20
# 579/579 [==============================] - 50s 87ms/step - loss: 0.1558 - accuracy: 0.9473 - f1_m: 0.9473 - recall_m: 0.9473 - precision_m: 0.9473 - val_loss: 0.0634 - val_accuracy: 0.9842 - val_f1_m: 0.9842 - val_recall_m: 0.9842 - val_precision_m: 0.9842
# Epoch 4/20
# 579/579 [==============================] - 51s 87ms/step - loss: 0.0776 - accuracy: 0.9760 - f1_m: 0.9760 - recall_m: 0.9760 - precision_m: 0.9760 - val_loss: 0.0367 - val_accuracy: 0.9918 - val_f1_m: 0.9918 - val_recall_m: 0.9918 - val_precision_m: 0.9918
# Epoch 5/20
# 579/579 [==============================] - 51s 87ms/step - loss: 0.0441 - accuracy: 0.9892 - f1_m: 0.9892 - recall_m: 0.9892 - precision_m: 0.9892 - val_loss: 0.0181 - val_accuracy: 0.9978 - val_f1_m: 0.9978 - val_recall_m: 0.9978 - val_precision_m: 0.9978
# Epoch 6/20
# 579/579 [==============================] - 51s 87ms/step - loss: 0.0362 - accuracy: 0.9896 - f1_m: 0.9896 - recall_m: 0.9896 - precision_m: 0.9896 - val_loss: 0.0343 - val_accuracy: 0.9927 - val_f1_m: 0.9927 - val_recall_m: 0.9927 - val_precision_m: 0.9927
# Epoch 7/20
# 579/579 [==============================] - 50s 87ms/step - loss: 0.0260 - accuracy: 0.9946 - f1_m: 0.9946 - recall_m: 0.9946 - precision_m: 0.9946 - val_loss: 0.0189 - val_accuracy: 0.9965 - val_f1_m: 0.9965 - val_recall_m: 0.9965 - val_precision_m: 0.9965
# Epoch 8/20
# 579/579 [==============================] - 51s 88ms/step - loss: 0.0226 - accuracy: 0.9957 - f1_m: 0.9957 - recall_m: 0.9957 - precision_m: 0.9957 - val_loss: 0.0106 - val_accuracy: 0.9987 - val_f1_m: 0.9987 - val_recall_m: 0.9987 - val_precision_m: 0.9987
# Epoch 9/20
# 579/579 [==============================] - 51s 88ms/step - loss: 0.0118 - accuracy: 0.9976 - f1_m: 0.9976 - recall_m: 0.9976 - precision_m: 0.9976 - val_loss: 0.0059 - val_accuracy: 0.9998 - val_f1_m: 0.9998 - val_recall_m: 0.9998 - val_precision_m: 0.9998
# Epoch 10/20
# 579/579 [==============================] - 51s 87ms/step - loss: 0.0109 - accuracy: 0.9978 - f1_m: 0.9978 - recall_m: 0.9978 - precision_m: 0.9978 - val_loss: 0.0158 - val_accuracy: 0.9976 - val_f1_m: 0.9976 - val_recall_m: 0.9976 - val_precision_m: 0.9976
# Epoch 11/20
# 579/579 [==============================] - 51s 87ms/step - loss: 0.0194 - accuracy: 0.9965 - f1_m: 0.9965 - recall_m: 0.9965 - precision_m: 0.9965 - val_loss: 0.0189 - val_accuracy: 0.9953 - val_f1_m: 0.9953 - val_recall_m: 0.9953 - val_precision_m: 0.9953
# Epoch 12/20
# 579/579 [==============================] - 51s 88ms/step - loss: 0.0124 - accuracy: 0.9974 - f1_m: 0.9974 - recall_m: 0.9974 - precision_m: 0.9974 - val_loss: 0.0062 - val_accuracy: 0.9996 - val_f1_m: 0.9996 - val_recall_m: 0.9996 - val_precision_m: 0.9996
# Epoch 13/20
# 579/579 [==============================] - 50s 87ms/step - loss: 0.0180 - accuracy: 0.9961 - f1_m: 0.9961 - recall_m: 0.9961 - precision_m: 0.9961 - val_loss: 0.0129 - val_accuracy: 0.9981 - val_f1_m: 0.9981 - val_recall_m: 0.9981 - val_precision_m: 0.9981
# Epoch 14/20
# 579/579 [==============================] - 50s 87ms/step - loss: 0.0154 - accuracy: 0.9968 - f1_m: 0.9968 - recall_m: 0.9968 - precision_m: 0.9968 - val_loss: 0.0134 - val_accuracy: 0.9987 - val_f1_m: 0.9987 - val_recall_m: 0.9987 - val_precision_m: 0.9987
# Epoch 15/20
# 579/579 [==============================] - 51s 88ms/step - loss: 0.0118 - accuracy: 0.9976 - f1_m: 0.9976 - recall_m: 0.9976 - precision_m: 0.9976 - val_loss: 0.0065 - val_accuracy: 0.9996 - val_f1_m: 0.9996 - val_recall_m: 0.9996 - val_precision_m: 0.9996
# Epoch 16/20
# 579/579 [==============================] - 51s 87ms/step - loss: 0.0044 - accuracy: 0.9998 - f1_m: 0.9998 - recall_m: 0.9998 - precision_m: 0.9998 - val_loss: 0.0023 - val_accuracy: 1.0000 - val_f1_m: 1.0000 - val_recall_m: 1.0000 - val_precision_m: 1.0000
# Epoch 17/20
# 579/579 [==============================] - 51s 88ms/step - loss: 0.0022 - accuracy: 1.0000 - f1_m: 1.0000 - recall_m: 1.0000 - precision_m: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - val_f1_m: 1.0000 - val_recall_m: 1.0000 - val_precision_m: 1.0000
# Epoch 18/20
# 579/579 [==============================] - 51s 87ms/step - loss: 0.0016 - accuracy: 1.0000 - f1_m: 1.0000 - recall_m: 1.0000 - precision_m: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - val_f1_m: 1.0000 - val_recall_m: 1.0000 - val_precision_m: 1.0000
# Epoch 19/20
# 579/579 [==============================] - 51s 88ms/step - loss: 0.0012 - accuracy: 1.0000 - f1_m: 1.0000 - recall_m: 1.0000 - precision_m: 1.0000 - val_loss: 9.1178e-04 - val_accuracy: 1.0000 - val_f1_m: 1.0000 - val_recall_m: 1.0000 - val_precision_m: 1.0000
# Epoch 20/20
# 579/579 [==============================] - 51s 88ms/step - loss: 0.0207 - accuracy: 0.9959 - f1_m: 0.9959 - recall_m: 0.9959 - precision_m: 0.9959 - val_loss: 0.0162 - val_accuracy: 0.9981 - val_f1_m: 0.9981 - val_recall_m: 0.9981 - val_precision_m: 0.9981

# %%
import matplotlib.pyplot as plt

x=history_LSTM
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(x.history['loss'], label='Training Loss')
plt.plot(x.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(x.history['accuracy'], label='Training Accuracy')
plt.plot(x.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
lstm1_acc = history_LSTM.history['val_accuracy'][19]
lstm1_prec = history_LSTM.history['val_precision_m'][19]
lstm1_rec = history_LSTM.history['val_recall_m'][19]
lstm1_f1 = history_LSTM.history['val_f1_m'][19]

# %%
storeResults('MS-LSTM',lstm1_acc,lstm1_prec,lstm1_rec,lstm1_f1)

# %% [markdown]
# # MS-SSA-LSTM

# %%
from tensorflow import keras

# %%
class SSA(keras.optimizers.Optimizer):
    def __init__(self, learning_rate=0.001, momentum=0.9, name="SSA", **kwargs):
        """Call super().__init__() and use _set_hyper() to store hyperparameters"""
        super().__init__(name, **kwargs)
        self._set_hyper("learning_rate", kwargs.get("lr", learning_rate)) # handle lr=learning_rate
        self._set_hyper("decay", self._initial_decay) # 
        self._set_hyper("momentum", momentum)
    
    def _create_slots(self, var_list):
        """For each model variable, create the optimizer variable associated with it.
        TensorFlow calls these optimizer variables "slots".
        For momentum optimization, we need one momentum slot per model variable.
        """
        for var in var_list:
            self.add_slot(var, "momentum")

    @tf.function
    def _resource_apply_dense(self, grad, var):
        """Update the slots and perform one optimization step for one model variable
        """
        var_dtype = var.dtype.base_dtype
        lr_t = self._decayed_lr(var_dtype) # handle learning rate decay
        momentum_var = self.get_slot(var, "momentum")
        momentum_hyper = self._get_hyper("momentum", var_dtype)
        momentum_var.assign(momentum_var * momentum_hyper - (1. - momentum_hyper)* grad)
        var.assign_add(momentum_var * lr_t)

    def _resource_apply_sparse(self, grad, var):
        raise NotImplementedError

    def get_config(self):
        base_config = super().get_config()
        return {
            **base_config,
            "learning_rate": self._serialize_hyperparameter("learning_rate"),
            "decay": self._serialize_hyperparameter("decay"),
            "momentum": self._serialize_hyperparameter("momentum"),
        }

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
optimizer=SSA()

# %%
embed_dim = 128 #dimension of the word embedding vector for each word in a sequence 
lstm_out = 196  #no of lstm layers
lstm_model = Sequential()
lstm_model.add(Embedding(num_words, embed_dim,input_length = X_train.shape[1]))
#Adding dropout
lstm_model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
#Adding a regularized dense layer
lstm_model.add(layers.Dense(32,kernel_regularizer=regularizers.l2(0.001),activation='relu'))
lstm_model.add(layers.Dropout(0.5))
lstm_model.add(Dense(2,activation='softmax'))
lstm_model.compile(loss = 'categorical_crossentropy', optimizer=optimizer,metrics = ['accuracy',f1_m,recall_m,precision_m])
#print(lstm_model.summary())

# %%
#model trained on the training data and taking validation data into account to avoid overfitting for 4 epochs 
history_LSTM=lstm_model.fit(X_train, Y_train, epochs = 20, batch_size=batch_size,validation_data=(X_test, Y_test),verbose = 1)
# Out:
# Epoch 1/20
# 579/579 [==============================] - 53s 89ms/step - loss: 0.5895 - accuracy: 0.7012 - f1_m: 0.7012 - recall_m: 0.7012 - precision_m: 0.7012 - val_loss: 0.3947 - val_accuracy: 0.8597 - val_f1_m: 0.8597 - val_recall_m: 0.8597 - val_precision_m: 0.8597
# Epoch 2/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.3621 - accuracy: 0.8605 - f1_m: 0.8605 - recall_m: 0.8605 - precision_m: 0.8605 - val_loss: 0.1820 - val_accuracy: 0.9575 - val_f1_m: 0.9575 - val_recall_m: 0.9575 - val_precision_m: 0.9575
# Epoch 3/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.1654 - accuracy: 0.9445 - f1_m: 0.9445 - recall_m: 0.9445 - precision_m: 0.9445 - val_loss: 0.0825 - val_accuracy: 0.9737 - val_f1_m: 0.9737 - val_recall_m: 0.9737 - val_precision_m: 0.9737
# Epoch 4/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0911 - accuracy: 0.9743 - f1_m: 0.9743 - recall_m: 0.9743 - precision_m: 0.9743 - val_loss: 0.0377 - val_accuracy: 0.9896 - val_f1_m: 0.9896 - val_recall_m: 0.9896 - val_precision_m: 0.9896
# Epoch 5/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0557 - accuracy: 0.9862 - f1_m: 0.9862 - recall_m: 0.9862 - precision_m: 0.9862 - val_loss: 0.0269 - val_accuracy: 0.9942 - val_f1_m: 0.9942 - val_recall_m: 0.9942 - val_precision_m: 0.9942
# Epoch 6/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0422 - accuracy: 0.9903 - f1_m: 0.9903 - recall_m: 0.9903 - precision_m: 0.9903 - val_loss: 0.0229 - val_accuracy: 0.9955 - val_f1_m: 0.9955 - val_recall_m: 0.9955 - val_precision_m: 0.9955
# Epoch 7/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0289 - accuracy: 0.9950 - f1_m: 0.9950 - recall_m: 0.9950 - precision_m: 0.9950 - val_loss: 0.0177 - val_accuracy: 0.9963 - val_f1_m: 0.9963 - val_recall_m: 0.9963 - val_precision_m: 0.9963
# Epoch 8/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0379 - accuracy: 0.9909 - f1_m: 0.9909 - recall_m: 0.9909 - precision_m: 0.9909 - val_loss: 0.0117 - val_accuracy: 0.9994 - val_f1_m: 0.9994 - val_recall_m: 0.9994 - val_precision_m: 0.9994
# Epoch 9/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0297 - accuracy: 0.9946 - f1_m: 0.9946 - recall_m: 0.9946 - precision_m: 0.9946 - val_loss: 0.0110 - val_accuracy: 0.9987 - val_f1_m: 0.9987 - val_recall_m: 0.9987 - val_precision_m: 0.9987
# Epoch 10/20
# 579/579 [==============================] - 52s 89ms/step - loss: 0.0227 - accuracy: 0.9955 - f1_m: 0.9955 - recall_m: 0.9955 - precision_m: 0.9955 - val_loss: 0.0093 - val_accuracy: 0.9991 - val_f1_m: 0.9991 - val_recall_m: 0.9991 - val_precision_m: 0.9991
# Epoch 11/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0136 - accuracy: 0.9976 - f1_m: 0.9976 - recall_m: 0.9976 - precision_m: 0.9976 - val_loss: 0.0083 - val_accuracy: 0.9989 - val_f1_m: 0.9989 - val_recall_m: 0.9989 - val_precision_m: 0.9989
# Epoch 12/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0086 - accuracy: 0.9987 - f1_m: 0.9987 - recall_m: 0.9987 - precision_m: 0.9987 - val_loss: 0.0041 - val_accuracy: 1.0000 - val_f1_m: 1.0000 - val_recall_m: 1.0000 - val_precision_m: 1.0000
# Epoch 13/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0104 - accuracy: 0.9974 - f1_m: 0.9974 - recall_m: 0.9974 - precision_m: 0.9974 - val_loss: 0.0047 - val_accuracy: 0.9998 - val_f1_m: 0.9998 - val_recall_m: 0.9998 - val_precision_m: 0.9998
# Epoch 14/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0173 - accuracy: 0.9968 - f1_m: 0.9968 - recall_m: 0.9968 - precision_m: 0.9968 - val_loss: 0.0112 - val_accuracy: 0.9976 - val_f1_m: 0.9976 - val_recall_m: 0.9976 - val_precision_m: 0.9976
# Epoch 15/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0193 - accuracy: 0.9953 - f1_m: 0.9953 - recall_m: 0.9953 - precision_m: 0.9953 - val_loss: 0.0103 - val_accuracy: 0.9983 - val_f1_m: 0.9983 - val_recall_m: 0.9983 - val_precision_m: 0.9983
# Epoch 16/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0153 - accuracy: 0.9965 - f1_m: 0.9965 - recall_m: 0.9965 - precision_m: 0.9965 - val_loss: 0.0107 - val_accuracy: 0.9978 - val_f1_m: 0.9978 - val_recall_m: 0.9978 - val_precision_m: 0.9978
# Epoch 17/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0099 - accuracy: 0.9987 - f1_m: 0.9987 - recall_m: 0.9987 - precision_m: 0.9987 - val_loss: 0.0054 - val_accuracy: 0.9989 - val_f1_m: 0.9989 - val_recall_m: 0.9989 - val_precision_m: 0.9989
# Epoch 18/20
# 579/579 [==============================] - 52s 90ms/step - loss: 0.0055 - accuracy: 0.9998 - f1_m: 0.9998 - recall_m: 0.9998 - precision_m: 0.9998 - val_loss: 0.0034 - val_accuracy: 0.9998 - val_f1_m: 0.9998 - val_recall_m: 0.9998 - val_precision_m: 0.9998
# Epoch 19/20
# 579/579 [==============================] - 53s 91ms/step - loss: 0.0060 - accuracy: 0.9985 - f1_m: 0.9985 - recall_m: 0.9985 - precision_m: 0.9985 - val_loss: 0.0067 - val_accuracy: 0.9989 - val_f1_m: 0.9989 - val_recall_m: 0.9989 - val_precision_m: 0.9989
# Epoch 20/20
# 579/579 [==============================] - 53s 92ms/step - loss: 0.0095 - accuracy: 0.9981 - f1_m: 0.9981 - recall_m: 0.9981 - precision_m: 0.9981 - val_loss: 0.0044 - val_accuracy: 0.9998 - val_f1_m: 0.9998 - val_recall_m: 0.9998 - val_precision_m: 0.9998

# %%
lstm2_acc = history_LSTM.history['val_accuracy'][19]
lstm2_prec = history_LSTM.history['val_precision_m'][19]
lstm2_rec = history_LSTM.history['val_recall_m'][19]
lstm2_f1 = history_LSTM.history['val_f1_m'][19]

# %%
storeResults('MS-SSA-LSTM',lstm2_acc,lstm2_prec,lstm2_rec,lstm2_f1)

# %%
import matplotlib.pyplot as plt

x=history_LSTM
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(x.history['loss'], label='Training Loss')
plt.plot(x.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(x.history['accuracy'], label='Training Accuracy')
plt.plot(x.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # LSTM + GRU

# %%
model = Sequential()
model.add(Embedding(num_words, embed_dim,input_length = X_train.shape[1]))
model.add(LSTM(64,dropout=0.4, recurrent_dropout=0.4,return_sequences=True))
model.add(GRU(32,dropout=0.5, recurrent_dropout=0.5,return_sequences=False))
model.add(Dense(2,activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy',f1_m,recall_m,precision_m])
#print(model.summary())

# %%
trained5 = model.fit(X_train, Y_train, epochs = 20, batch_size=batch_size,validation_data=(X_test, Y_test),verbose = 1)
# Out:
# Epoch 1/20
# 579/579 [==============================] - 29s 45ms/step - loss: 0.5531 - accuracy: 0.7066 - f1_m: 0.7066 - recall_m: 0.7066 - precision_m: 0.7066 - val_loss: 0.3024 - val_accuracy: 0.8800 - val_f1_m: 0.8800 - val_recall_m: 0.8800 - val_precision_m: 0.8800
# Epoch 2/20
# 579/579 [==============================] - 26s 45ms/step - loss: 0.3177 - accuracy: 0.8659 - f1_m: 0.8659 - recall_m: 0.8659 - precision_m: 0.8659 - val_loss: 0.1623 - val_accuracy: 0.9603 - val_f1_m: 0.9603 - val_recall_m: 0.9603 - val_precision_m: 0.9603
# Epoch 3/20
# 579/579 [==============================] - 40s 69ms/step - loss: 0.1552 - accuracy: 0.9417 - f1_m: 0.9417 - recall_m: 0.9417 - precision_m: 0.9417 - val_loss: 0.0531 - val_accuracy: 0.9816 - val_f1_m: 0.9816 - val_recall_m: 0.9816 - val_precision_m: 0.9816
# Epoch 4/20
# 579/579 [==============================] - 39s 67ms/step - loss: 0.0766 - accuracy: 0.9724 - f1_m: 0.9724 - recall_m: 0.9724 - precision_m: 0.9724 - val_loss: 0.0359 - val_accuracy: 0.9881 - val_f1_m: 0.9881 - val_recall_m: 0.9881 - val_precision_m: 0.9881.9725 - recall_m
# Epoch 5/20
# 579/579 [==============================] - 39s 68ms/step - loss: 0.0419 - accuracy: 0.9853 - f1_m: 0.9853 - recall_m: 0.9853 - precision_m: 0.9853 - val_loss: 0.0296 - val_accuracy: 0.9914 - val_f1_m: 0.9914 - val_recall_m: 0.9914 - val_precision_m: 0.9914
# Epoch 6/20
# 579/579 [==============================] - 40s 69ms/step - loss: 0.0272 - accuracy: 0.9907 - f1_m: 0.9907 - recall_m: 0.9907 - precision_m: 0.9907 - val_loss: 0.0047 - val_accuracy: 0.9994 - val_f1_m: 0.9994 - val_recall_m: 0.9994 - val_precision_m: 0.9994
# Epoch 7/20
# 579/579 [==============================] - 40s 70ms/step - loss: 0.0110 - accuracy: 0.9963 - f1_m: 0.9963 - recall_m: 0.9963 - precision_m: 0.9963 - val_loss: 0.0033 - val_accuracy: 0.9989 - val_f1_m: 0.9989 - val_recall_m: 0.9989 - val_precision_m: 0.9989
# Epoch 8/20
# 579/579 [==============================] - 41s 70ms/step - loss: 0.0276 - accuracy: 0.9909 - f1_m: 0.9909 - recall_m: 0.9909 - precision_m: 0.9909 - val_loss: 0.0357 - val_accuracy: 0.9918 - val_f1_m: 0.9918 - val_recall_m: 0.9918 - val_precision_m: 0.9918
# Epoch 9/20
# 579/579 [==============================] - 41s 70ms/step - loss: 0.0161 - accuracy: 0.9950 - f1_m: 0.9950 - recall_m: 0.9950 - precision_m: 0.9950 - val_loss: 0.0029 - val_accuracy: 0.9989 - val_f1_m: 0.9989 - val_recall_m: 0.9989 - val_precision_m: 0.9989
# Epoch 10/20
# 579/579 [==============================] - 40s 70ms/step - loss: 0.0113 - accuracy: 0.9963 - f1_m: 0.9963 - recall_m: 0.9963 - precision_m: 0.9963 - val_loss: 0.0016 - val_accuracy: 0.9998 - val_f1_m: 0.9998 - val_recall_m: 0.9998 - val_precision_m: 0.9998
# Epoch 11/20
# 579/579 [==============================] - 41s 70ms/step - loss: 0.0146 - accuracy: 0.9957 - f1_m: 0.9957 - recall_m: 0.9957 - precision_m: 0.9957 - val_loss: 0.0045 - val_accuracy: 0.9991 - val_f1_m: 0.9991 - val_recall_m: 0.9991 - val_precision_m: 0.9991
# Epoch 12/20
# 579/579 [==============================] - 40s 70ms/step - loss: 0.0127 - accuracy: 0.9965 - f1_m: 0.9965 - recall_m: 0.9965 - precision_m: 0.9965 - val_loss: 0.0045 - val_accuracy: 0.9985 - val_f1_m: 0.9985 - val_recall_m: 0.9985 - val_precision_m: 0.9985
# Epoch 13/20
# 579/579 [==============================] - 40s 70ms/step - loss: 0.0068 - accuracy: 0.9987 - f1_m: 0.9987 - recall_m: 0.9987 - precision_m: 0.9987 - val_loss: 0.0054 - val_accuracy: 0.9985 - val_f1_m: 0.9985 - val_recall_m: 0.9985 - val_precision_m: 0.9985
# Epoch 14/20
# 579/579 [==============================] - 40s 69ms/step - loss: 0.0064 - accuracy: 0.9983 - f1_m: 0.9983 - recall_m: 0.9983 - precision_m: 0.9983 - val_loss: 5.6072e-04 - val_accuracy: 0.9998 - val_f1_m: 0.9998 - val_recall_m: 0.9998 - val_precision_m: 0.9998
# Epoch 15/20
# 579/579 [==============================] - 40s 70ms/step - loss: 0.0061 - accuracy: 0.9989 - f1_m: 0.9989 - recall_m: 0.9989 - precision_m: 0.9989 - val_loss: 0.0025 - val_accuracy: 0.9994 - val_f1_m: 0.9994 - val_recall_m: 0.9994 - val_precision_m: 0.9994
# Epoch 16/20
# 579/579 [==============================] - 41s 70ms/step - loss: 0.0081 - accuracy: 0.9974 - f1_m: 0.9974 - recall_m: 0.9974 - precision_m: 0.9974 - val_loss: 0.0010 - val_accuracy: 0.9998 - val_f1_m: 0.9998 - val_recall_m: 0.9998 - val_precision_m: 0.9998
# Epoch 17/20
# 579/579 [==============================] - 41s 70ms/step - loss: 0.0072 - accuracy: 0.9981 - f1_m: 0.9981 - recall_m: 0.9981 - precision_m: 0.9981 - val_loss: 7.6755e-04 - val_accuracy: 0.9998 - val_f1_m: 0.9998 - val_recall_m: 0.9998 - val_precision_m: 0.9998
# Epoch 18/20
# 579/579 [==============================] - 41s 70ms/step - loss: 0.0037 - accuracy: 0.9989 - f1_m: 0.9989 - recall_m: 0.9989 - precision_m: 0.9989 - val_loss: 0.0048 - val_accuracy: 0.9991 - val_f1_m: 0.9991 - val_recall_m: 0.9991 - val_precision_m: 0.9991
# Epoch 19/20
# 579/579 [==============================] - 42s 72ms/step - loss: 0.0085 - accuracy: 0.9963 - f1_m: 0.9963 - recall_m: 0.9963 - precision_m: 0.9963 - val_loss: 0.0021 - val_accuracy: 0.9994 - val_f1_m: 0.9994 - val_recall_m: 0.9994 - val_precision_m: 0.9994
# Epoch 20/20
# 579/579 [==============================] - 48s 83ms/step - loss: 0.0040 - accuracy: 0.9985 - f1_m: 0.9985 - recall_m: 0.9985 - precision_m: 0.9985 - val_loss: 9.6406e-04 - val_accuracy: 0.9998 - val_f1_m: 0.9998 - val_recall_m: 0.9998 - val_precision_m: 0.9998

# %%
hyb_acc = history_LSTM.history['val_accuracy'][19]
hyb_prec = history_LSTM.history['val_precision_m'][19]
hyb_rec = history_LSTM.history['val_recall_m'][19]
hyb_f1 = history_LSTM.history['val_f1_m'][19]

# %%
storeResults('LSTM-GRU',hyb_acc,hyb_prec,hyb_rec,hyb_f1)

# %%
import matplotlib.pyplot as plt

x=trained5
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(x.history['loss'], label='Training Loss')
plt.plot(x.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(x.history['accuracy'], label='Training Accuracy')
plt.plot(x.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Stock Price

# %%
dataset=pd.read_csv('data/Stock_Price_Train.csv',index_col="Date",parse_dates=True)

# %%
dataset.head()
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59   7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45   5,749,400
# 2012-01-05  329.83  330.75  326.89  657.21   6,590,300
# 2012-01-06  328.34  328.77  323.68  648.24   5,405,900
# 2012-01-09  322.04  322.29  309.46  620.76  11,688,800

# %%
dataset.isna().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
dataset['Open'].plot(figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %%
# convert column "a" of a DataFrame
dataset["Close"] = dataset["Close"].str.replace(',', '').astype(float)

# %%
dataset["Volume"] = dataset["Volume"].str.replace(',', '').astype(float)

# %%
# 7 day rolling mean
dataset.rolling(7).mean().head(20)
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2012-01-03         NaN         NaN         NaN         NaN           NaN
# 2012-01-04         NaN         NaN         NaN         NaN           NaN
# 2012-01-05         NaN         NaN         NaN         NaN           NaN
# 2012-01-06         NaN         NaN         NaN         NaN           NaN
# 2012-01-09         NaN         NaN         NaN         NaN           NaN
# 2012-01-10         NaN         NaN         NaN         NaN           NaN
# 2012-01-11  323.002857  325.392857  318.682857  643.132857  7.208100e+06
# 2012-01-12  321.457143  322.882857  316.841429  638.037143  6.691514e+06
# 2012-01-13  318.698571  319.801429  314.025714  631.870000  6.531857e+06
# 2012-01-17  316.552857  317.524286  311.851429  627.534286  6.137929e+06
# 2012-01-18  314.238571  315.674286  309.882857  625.097143  6.157657e+06
# 2012-01-19  313.847143  315.247143  310.610000  627.534286  6.296086e+06
# 2012-01-20  311.055714  312.201429  308.104286  622.242857  8.068629e+06
# 2012-01-23  308.387143  309.302857  305.402857  616.481429  8.359129e+06
# 2012-01-24  305.192857  306.085714  301.951429  609.541429  8.697700e+06
# 2012-01-25  301.724286  302.652857  298.060000  601.634286  9.466400e+06
# 2012-01-26  297.454286  298.561429  293.710000  593.017143  9.844071e+06
# 2012-01-27  293.480000  294.741429  289.952857  585.475714  1.008950e+07
# 2012-01-30  289.001429  290.401429  285.821429  576.660000  8.949586e+06
# 2012-01-31  288.465714  289.902857  285.355714  575.821429  6.530857e+06

# %%
dataset['Open'].plot(figsize=(16,6))
dataset.rolling(window=30).mean()['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
dataset['Close: 30 Day Mean'] = dataset['Close'].rolling(window=30).mean()
dataset[['Close','Close: 30 Day Mean']].plot(figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %%
# Optional specify a minimum number of periods
dataset['Close'].expanding(min_periods=1).mean().plot(figsize=(16,6))
# Out:
# <Axes: xlabel='Date'>

# %%
training_set=dataset['Open']
training_set=pd.DataFrame(training_set)

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Creating a data structure with 60 timesteps and 1 output
X_train = []
y_train = []
for i in range(60, 1258):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from numpy import sqrt

# %%
ML_Model1 = []
r2 = []
mse = []
rmse = []
mae = []

#function to call for storing the results
def storeResults1(model, a,b,c,d):
    ML_Model1.append(model)
    r2.append(round(a, 3))
    mse.append(round(d, 3))
    rmse.append(round(c, 3))
    mae.append(round(b, 3))

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor(random_state=1, max_iter=500)
mlp.fit(X_train, y_train) 
y_pred = mlp.predict(X_train)

# %%
r_mlp = r2_score(y_train, y_pred)
mse_mlp = mean_squared_error(y_train, y_pred)
rmse_mlp = sqrt(mse_mlp)
mae_mlp = mean_absolute_error(y_train, y_pred)

# %%
storeResults1('MLP',r_mlp,mse_mlp,rmse_mlp,mae_mlp)

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor()
xgb.fit(X_train, y_train) 
y_pred = xgb.predict(X_train)

r_xgb = r2_score(y_train, y_pred)
mse_xgb = mean_squared_error(y_train, y_pred)
rmse_xgb = sqrt(mse_xgb)
mae_xgb = mean_absolute_error(y_train, y_pred)

# %%
storeResults1('XGBoost',r_xgb,mse_xgb,rmse_xgb,mae_xgb)

# %% [markdown]
# # Voting Regressor

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.neighbors import KNeighborsRegressor

r1 = LinearRegression()
r2 = RandomForestRegressor(n_estimators=10, random_state=1)
r3 = KNeighborsRegressor()

eclf1 = VotingRegressor([('lr', r1), ('rf', r2), ('r3', r3)])
eclf1.fit(X_train, y_train)
y_pred = eclf1.predict(X_train)

# %%
r_vot = r2_score(y_train, y_pred)
mse_vot = mean_squared_error(y_train, y_pred)
rmse_vot = sqrt(mse_vot)
mae_vot = mean_absolute_error(y_train, y_pred)

# %%
storeResults1('Voting Regressor',r_vot,mse_vot,rmse_vot,mae_vot)

# %% [markdown]
# DL

# %%
# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# # CNN

# %%
from tensorflow.keras import Sequential,utils
from tensorflow.keras.layers import Flatten, Dense, Conv1D, MaxPool1D, Dropout

def reg():
    
    model = Sequential()
    
    model.add(Conv1D(32, kernel_size=(3,), padding='same', activation='relu', input_shape = (X_train.shape[1],1)))
    model.add(Conv1D(64, kernel_size=(3,), padding='same', activation='relu'))
    model.add(Conv1D(128, kernel_size=(5,), padding='same', activation='relu'))
    
    model.add(Flatten())
    
    model.add(Dense(50, activation='relu'))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(units = 1))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model

# %%
model_3 = reg()
model_3.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 2s 28ms/step - loss: 0.0161 - val_loss: 0.0036
# Epoch 2/100
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0041
# Epoch 3/100
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 4/100
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0016 - val_loss: 0.0059
# Epoch 5/100
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 6/100
# 30/30 [==============================] - 1s 22ms/step - loss: 8.9937e-04 - val_loss: 0.0011
# Epoch 7/100
# 30/30 [==============================] - 1s 21ms/step - loss: 7.9881e-04 - val_loss: 0.0013
# Epoch 8/100
# 30/30 [==============================] - 1s 18ms/step - loss: 9.4659e-04 - val_loss: 7.1106e-04
# Epoch 9/100
# 30/30 [==============================] - 1s 20ms/step - loss: 6.5131e-04 - val_loss: 0.0012
# Epoch 10/100
# 30/30 [==============================] - 1s 22ms/step - loss: 5.1098e-04 - val_loss: 0.0012
# Epoch 11/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.8335e-04 - val_loss: 5.8433e-04
# Epoch 12/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.7626e-04 - val_loss: 9.9386e-04
# Epoch 13/100
# 30/30 [==============================] - 1s 21ms/step - loss: 4.6288e-04 - val_loss: 6.4520e-04
# Epoch 14/100
# 30/30 [==============================] - 1s 18ms/step - loss: 8.4781e-04 - val_loss: 0.0033
# Epoch 15/100
# 30/30 [==============================] - 1s 21ms/step - loss: 6.5219e-04 - val_loss: 8.6407e-04
# Epoch 16/100
# 30/30 [==============================] - 1s 22ms/step - loss: 3.3677e-04 - val_loss: 0.0012
# Epoch 17/100
# 30/30 [==============================] - 1s 27ms/step - loss: 3.6185e-04 - val_loss: 0.0017
# Epoch 18/100
# 30/30 [==============================] - 1s 22ms/step - loss: 3.7017e-04 - val_loss: 3.9152e-04
# Epoch 19/100
# 30/30 [==============================] - 1s 21ms/step - loss: 3.1982e-04 - val_loss: 6.2256e-04
# Epoch 20/100
# 30/30 [==============================] - 1s 17ms/step - loss: 4.2463e-04 - val_loss: 3.8931e-04
# Epoch 21/100
# 30/30 [==============================] - 1s 18ms/step - loss: 5.0877e-04 - val_loss: 7.1343e-04
# Epoch 22/100
# 30/30 [==============================] - 1s 21ms/step - loss: 3.4083e-04 - val_loss: 9.1868e-04
# Epoch 23/100
# 30/30 [==============================] - 1s 26ms/step - loss: 3.3298e-04 - val_loss: 4.4164e-04
# Epoch 24/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.1585e-04 - val_loss: 4.3171e-04
# Epoch 25/100
# 30/30 [==============================] - 1s 22ms/step - loss: 2.8047e-04 - val_loss: 5.5192e-04
# Epoch 26/100
# 30/30 [==============================] - 1s 18ms/step - loss: 2.8351e-04 - val_loss: 3.6061e-04
# Epoch 27/100
# 30/30 [==============================] - 1s 19ms/step - loss: 2.7788e-04 - val_loss: 0.0010
# Epoch 28/100
# 30/30 [==============================] - 1s 21ms/step - loss: 4.4894e-04 - val_loss: 0.0011
# Epoch 29/100
# 30/30 [==============================] - 1s 26ms/step - loss: 3.6143e-04 - val_loss: 8.6981e-04
# Epoch 30/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.4800e-04 - val_loss: 3.7742e-04
# Epoch 31/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.9171e-04 - val_loss: 6.9536e-04
# Epoch 32/100
# 30/30 [==============================] - 1s 19ms/step - loss: 2.6042e-04 - val_loss: 3.7241e-04
# Epoch 33/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.7851e-04 - val_loss: 6.4373e-04
# Epoch 34/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.8181e-04 - val_loss: 4.0911e-04
# Epoch 35/100
# 30/30 [==============================] - 1s 27ms/step - loss: 2.7684e-04 - val_loss: 4.4460e-04
# Epoch 36/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.5676e-04 - val_loss: 5.3377e-04
# Epoch 37/100
# 30/30 [==============================] - 1s 22ms/step - loss: 2.4439e-04 - val_loss: 9.1752e-04
# Epoch 38/100
# 30/30 [==============================] - 1s 19ms/step - loss: 2.6781e-04 - val_loss: 5.8418e-04
# Epoch 39/100
# 30/30 [==============================] - 1s 18ms/step - loss: 2.8359e-04 - val_loss: 7.7941e-04
# Epoch 40/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.7685e-04 - val_loss: 6.0764e-04
# Epoch 41/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.4359e-04 - val_loss: 3.9313e-04
# Epoch 42/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.7195e-04 - val_loss: 6.0987e-04
# Epoch 43/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.9189e-04 - val_loss: 5.9960e-04
# Epoch 44/100
# 30/30 [==============================] - 1s 20ms/step - loss: 3.3804e-04 - val_loss: 6.5032e-04
# Epoch 45/100
# 30/30 [==============================] - 1s 18ms/step - loss: 2.7699e-04 - val_loss: 9.7587e-04
# Epoch 46/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.7693e-04 - val_loss: 0.0010
# Epoch 47/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.0923e-04 - val_loss: 3.5008e-04
# Epoch 48/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.9423e-04 - val_loss: 4.2938e-04
# Epoch 49/100
# 30/30 [==============================] - 1s 22ms/step - loss: 2.9855e-04 - val_loss: 7.5287e-04
# Epoch 50/100
# 30/30 [==============================] - 1s 19ms/step - loss: 2.7112e-04 - val_loss: 4.7324e-04
# Epoch 51/100
# 30/30 [==============================] - 1s 18ms/step - loss: 2.6955e-04 - val_loss: 3.6507e-04
# Epoch 52/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.7516e-04 - val_loss: 0.0013
# Epoch 53/100
# 30/30 [==============================] - 1s 22ms/step - loss: 3.3862e-04 - val_loss: 3.6179e-04
# Epoch 54/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.0133e-04 - val_loss: 6.8699e-04
# Epoch 55/100
# 30/30 [==============================] - 1s 22ms/step - loss: 3.8512e-04 - val_loss: 0.0034
# Epoch 56/100
# 30/30 [==============================] - 1s 21ms/step - loss: 3.4555e-04 - val_loss: 7.3593e-04
# Epoch 57/100
# 30/30 [==============================] - 1s 18ms/step - loss: 2.4828e-04 - val_loss: 5.4745e-04
# Epoch 58/100
# 30/30 [==============================] - 1s 19ms/step - loss: 2.8529e-04 - val_loss: 7.8712e-04
# Epoch 59/100
# 30/30 [==============================] - 1s 22ms/step - loss: 2.6343e-04 - val_loss: 5.8920e-04
# Epoch 60/100
# 30/30 [==============================] - 1s 27ms/step - loss: 2.7121e-04 - val_loss: 7.5613e-04
# Epoch 61/100
# 30/30 [==============================] - 1s 27ms/step - loss: 2.5059e-04 - val_loss: 4.1961e-04
# Epoch 62/100
# 30/30 [==============================] - 1s 22ms/step - loss: 2.4004e-04 - val_loss: 0.0014
# Epoch 63/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.0807e-04 - val_loss: 4.0877e-04
# Epoch 64/100
# 30/30 [==============================] - 1s 18ms/step - loss: 2.5522e-04 - val_loss: 3.6273e-04
# Epoch 65/100
# 30/30 [==============================] - 1s 23ms/step - loss: 2.3152e-04 - val_loss: 3.4675e-04
# Epoch 66/100
# 30/30 [==============================] - 1s 25ms/step - loss: 2.3748e-04 - val_loss: 6.8774e-04
# Epoch 67/100
# 30/30 [==============================] - 1s 21ms/step - loss: 3.1944e-04 - val_loss: 7.0179e-04
# Epoch 68/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.8582e-04 - val_loss: 4.8501e-04
# Epoch 69/100
# 30/30 [==============================] - 1s 18ms/step - loss: 2.8942e-04 - val_loss: 9.3420e-04
# Epoch 70/100
# 30/30 [==============================] - 1s 19ms/step - loss: 3.4996e-04 - val_loss: 0.0016
# Epoch 71/100
# 30/30 [==============================] - 1s 22ms/step - loss: 3.0725e-04 - val_loss: 9.5031e-04
# Epoch 72/100
# 30/30 [==============================] - 1s 29ms/step - loss: 4.6967e-04 - val_loss: 9.2293e-04
# Epoch 73/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.9320e-04 - val_loss: 7.3112e-04
# Epoch 74/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.3125e-04 - val_loss: 4.2356e-04
# Epoch 75/100
# 30/30 [==============================] - 1s 18ms/step - loss: 2.3966e-04 - val_loss: 0.0017
# Epoch 76/100
# 30/30 [==============================] - 1s 18ms/step - loss: 2.4919e-04 - val_loss: 4.1622e-04
# Epoch 77/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.2653e-04 - val_loss: 3.8257e-04
# Epoch 78/100
# 30/30 [==============================] - 1s 27ms/step - loss: 2.2525e-04 - val_loss: 6.3588e-04
# Epoch 79/100
# 30/30 [==============================] - 1s 23ms/step - loss: 2.2032e-04 - val_loss: 4.2237e-04
# Epoch 80/100
# 30/30 [==============================] - 1s 23ms/step - loss: 2.1297e-04 - val_loss: 0.0011
# Epoch 81/100
# 30/30 [==============================] - 1s 19ms/step - loss: 3.0194e-04 - val_loss: 3.5781e-04
# Epoch 82/100
# 30/30 [==============================] - 1s 24ms/step - loss: 3.1277e-04 - val_loss: 4.8896e-04
# Epoch 83/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.1703e-04 - val_loss: 0.0011
# Epoch 84/100
# 30/30 [==============================] - 1s 27ms/step - loss: 2.4809e-04 - val_loss: 3.5833e-04
# Epoch 85/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.4034e-04 - val_loss: 3.6293e-04
# Epoch 86/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.0944e-04 - val_loss: 4.1033e-04
# Epoch 87/100
# 30/30 [==============================] - 1s 17ms/step - loss: 2.3748e-04 - val_loss: 4.1190e-04
# Epoch 88/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.4010e-04 - val_loss: 6.3203e-04
# Epoch 89/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.3424e-04 - val_loss: 3.9059e-04
# Epoch 90/100
# 30/30 [==============================] - 1s 25ms/step - loss: 2.2282e-04 - val_loss: 4.3708e-04
# Epoch 91/100
# 30/30 [==============================] - 1s 22ms/step - loss: 2.2396e-04 - val_loss: 4.0814e-04
# Epoch 92/100
# 30/30 [==============================] - 1s 21ms/step - loss: 2.3299e-04 - val_loss: 4.0383e-04
# Epoch 93/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.9989e-04 - val_loss: 5.1317e-04
# Epoch 94/100
# 30/30 [==============================] - 1s 19ms/step - loss: 2.4725e-04 - val_loss: 4.3265e-04
# Epoch 95/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.1615e-04 - val_loss: 4.6482e-04
# Epoch 96/100
# 30/30 [==============================] - 1s 23ms/step - loss: 1.9470e-04 - val_loss: 4.5803e-04
# Epoch 97/100
# 30/30 [==============================] - 1s 23ms/step - loss: 2.0728e-04 - val_loss: 5.1925e-04
# Epoch 98/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.9646e-04 - val_loss: 6.1096e-04
# Epoch 99/100
# 30/30 [==============================] - 1s 19ms/step - loss: 2.4285e-04 - val_loss: 6.2419e-04
# Epoch 100/100
# 30/30 [==============================] - 0s 17ms/step - loss: 2.4558e-04 - val_loss: 4.2900e-04

# %%
# Prediction

y_pred_3 = model_3.predict(X_train)

# %%
r_cnn = r2_score(y_train, y_pred_3)
mse_cnn = mean_squared_error(y_train, y_pred_3)
rmse_cnn = sqrt(mse_vot)
mae_cnn = mean_absolute_error(y_train, y_pred_3)

# %%
storeResults1('CNN',r_cnn,mse_cnn,rmse_cnn,mae_cnn)

# %%
pred_df = pd.DataFrame({'Actual': y_train, 'Predicted': y_pred_3.flatten()})
pred_df.head()
# Out:
#      Actual  Predicted
# 0  0.086279   0.082659
# 1  0.084716   0.079603
# 2  0.074541   0.079564
# 3  0.078838   0.075187
# 4  0.072383   0.073143

# %%
plt.figure(figsize=(8,8))
plt.ylabel('Close Price', fontsize=16)
plt.plot(pred_df)
plt.legend(['Actual Value', 'Predictions'])
plt.show()

# %% [markdown]
# # LSTM

# %%
# Initialising the RNN
regressor = Sequential()
# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 15s 136ms/step - loss: 0.0444
# Epoch 2/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0064
# Epoch 3/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0052
# Epoch 4/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0049
# Epoch 5/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0051
# Epoch 6/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0047
# Epoch 7/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0046
# Epoch 8/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0045
# Epoch 9/100
# 38/38 [==============================] - 5s 145ms/step - loss: 0.0042
# Epoch 10/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0042
# Epoch 11/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0041
# Epoch 12/100
# 38/38 [==============================] - 6s 148ms/step - loss: 0.0042
# Epoch 13/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0040
# Epoch 14/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0037
# Epoch 15/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0038 1s - los
# Epoch 16/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0039
# Epoch 17/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0034
# Epoch 18/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0034
# Epoch 19/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0041
# Epoch 20/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0035
# Epoch 21/100
# 38/38 [==============================] - 6s 149ms/step - loss: 0.0042
# Epoch 22/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0036
# Epoch 23/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0035
# Epoch 24/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0031
# Epoch 25/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0035
# Epoch 26/100
# 38/38 [==============================] - 5s 145ms/step - loss: 0.0032
# Epoch 27/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0033
# Epoch 28/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0027
# Epoch 29/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0027
# Epoch 30/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0030
# Epoch 31/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0027
# Epoch 32/100
# 38/38 [==============================] - 6s 148ms/step - loss: 0.0028
# Epoch 33/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0030
# Epoch 34/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0027
# Epoch 35/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0031
# Epoch 36/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0032
# Epoch 37/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0029
# Epoch 38/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0027
# Epoch 39/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0030
# Epoch 40/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0025
# Epoch 41/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0024
# Epoch 42/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0025
# Epoch 43/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0025
# Epoch 44/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0026 1s - lo
# Epoch 45/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0030
# Epoch 46/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0025
# Epoch 47/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0023
# Epoch 48/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0025
# Epoch 49/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0023
# Epoch 50/100
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0028
# Epoch 51/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0025
# Epoch 52/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0025
# Epoch 53/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0022
# Epoch 54/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0022
# Epoch 55/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0020
# Epoch 56/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0020 1s
# Epoch 57/100
# 38/38 [==============================] - 6s 159ms/step - loss: 0.0023
# Epoch 58/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0020
# Epoch 59/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0020
# Epoch 60/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0021
# Epoch 61/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0019
# Epoch 62/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0020
# Epoch 63/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0019
# Epoch 64/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0020
# Epoch 65/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0021
# Epoch 66/100
# 38/38 [==============================] - 6s 148ms/step - loss: 0.0022
# Epoch 67/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0018
# Epoch 68/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0022
# Epoch 69/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0018
# Epoch 70/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0017
# Epoch 71/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0019
# Epoch 72/100
# 38/38 [==============================] - 5s 145ms/step - loss: 0.0019
# Epoch 73/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0019
# Epoch 74/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0017
# Epoch 75/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0018
# Epoch 76/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0019
# Epoch 77/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0019
# Epoch 78/100
# 38/38 [==============================] - 5s 145ms/step - loss: 0.0019
# Epoch 79/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0015
# Epoch 80/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0016
# Epoch 81/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0016
# Epoch 82/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0017
# Epoch 83/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0015
# Epoch 84/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0016
# Epoch 85/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0016
# Epoch 86/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0015
# Epoch 87/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0017
# Epoch 88/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0016
# Epoch 89/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0016
# Epoch 90/100
# 38/38 [==============================] - 6s 148ms/step - loss: 0.0017
# Epoch 91/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0017
# Epoch 92/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0015
# Epoch 93/100
# 38/38 [==============================] - 6s 144ms/step - loss: 0.0015
# Epoch 94/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0015
# Epoch 95/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0016
# Epoch 96/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0015
# Epoch 97/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0014
# Epoch 98/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0014
# Epoch 99/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0015
# Epoch 100/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0015

# %%
# Prediction

y_pred_3 = regressor.predict(X_train)

# %%
r_lstm = r2_score(y_train, y_pred_3)
mse_lstm = mean_squared_error(y_train, y_pred_3)
rmse_lstm = sqrt(mse_lstm)
mae_lstm = mean_absolute_error(y_train, y_pred_3)

# %%
storeResults1('LSTM',r_lstm,mse_lstm,rmse_lstm,mae_lstm)

# %%
pred_df = pd.DataFrame({'Actual': y_train, 'Predicted': y_pred_3.flatten()})
pred_df.head()
# Out:
#      Actual  Predicted
# 0  0.086279   0.075241
# 1  0.084716   0.077212
# 2  0.074541   0.078589
# 3  0.078838   0.078048
# 4  0.072383   0.076132

# %%
plt.figure(figsize=(8,8))
plt.ylabel('Close Price', fontsize=16)
plt.plot(pred_df)
plt.legend(['Actual Value', 'Predictions'])
plt.show()

# %% [markdown]
# # MS-LSTM

# %% [markdown]
# Multi-Stock data

# %%
dataset=pd.read_csv('data/all_stocks_5yr.csv',index_col="date",parse_dates=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 619040 entries, 2013-02-08 to 2018-02-07
# Data columns (total 6 columns):
# open      619029 non-null float64
# high      619032 non-null float64
# low       619032 non-null float64
# close     619040 non-null float64
# volume    619040 non-null int64
# Name      619040 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 33.1+ MB

# %%
dataset.head()
# Out:
#              open   high    low  close    volume Name
# date
# 2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
dataset = dataset.dropna()

# %%
dataset.isna().sum()
# Out:
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
dataset['open'].plot(figsize=(16,6))

# %%
training_set=dataset['open']
training_set=pd.DataFrame(training_set)

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Creating a data structure with 60 timesteps and 1 output
X_train = []
y_train = []
for i in range(60, 10000):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# Initialising the RNN
regressor = Sequential()
# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 311/311 [==============================] - 54s 143ms/step - loss: 6.5594e-05
# Epoch 2/100
# 311/311 [==============================] - 45s 143ms/step - loss: 2.1701e-05
# Epoch 3/100
# 311/311 [==============================] - 44s 143ms/step - loss: 1.7339e-05
# Epoch 4/100
# 311/311 [==============================] - 45s 143ms/step - loss: 1.4427e-05
# Epoch 5/100
# 311/311 [==============================] - 44s 143ms/step - loss: 1.3043e-05
# Epoch 6/100
# 311/311 [==============================] - 44s 142ms/step - loss: 1.1472e-05
# Epoch 7/100
# 311/311 [==============================] - 45s 144ms/step - loss: 1.1638e-05
# Epoch 8/100
# 311/311 [==============================] - 44s 143ms/step - loss: 1.0484e-05
# Epoch 9/100
# 311/311 [==============================] - 45s 144ms/step - loss: 1.0392e-05
# Epoch 10/100
# 311/311 [==============================] - 44s 143ms/step - loss: 9.5299e-06
# Epoch 11/100
# 311/311 [==============================] - 44s 142ms/step - loss: 9.2005e-06
# Epoch 12/100
# 311/311 [==============================] - 45s 143ms/step - loss: 9.1560e-06
# Epoch 13/100
# 311/311 [==============================] - 44s 143ms/step - loss: 9.1829e-06
# Epoch 14/100
# 311/311 [==============================] - 44s 143ms/step - loss: 9.1609e-06
# Epoch 15/100
# 311/311 [==============================] - 45s 143ms/step - loss: 8.4364e-06
# Epoch 16/100
# 311/311 [==============================] - 44s 143ms/step - loss: 8.1372e-06
# Epoch 17/100
# 311/311 [==============================] - 44s 143ms/step - loss: 8.3055e-06
# Epoch 18/100
# 311/311 [==============================] - 44s 143ms/step - loss: 7.6018e-06
# Epoch 19/100
# 311/311 [==============================] - 44s 143ms/step - loss: 7.6744e-06
# Epoch 20/100
# 311/311 [==============================] - 45s 144ms/step - loss: 8.3368e-06
# Epoch 21/100
# 311/311 [==============================] - 45s 143ms/step - loss: 7.5334e-06
# Epoch 22/100
# 311/311 [==============================] - 45s 143ms/step - loss: 7.1596e-06
# Epoch 23/100
# 311/311 [==============================] - 45s 143ms/step - loss: 7.1359e-06
# Epoch 24/100
# 311/311 [==============================] - 44s 143ms/step - loss: 7.0584e-06
# Epoch 25/100
# 311/311 [==============================] - 44s 143ms/step - loss: 6.9802e-06
# Epoch 26/100
# 311/311 [==============================] - 44s 143ms/step - loss: 6.6641e-06
# Epoch 27/100
# 311/311 [==============================] - 44s 143ms/step - loss: 6.5443e-06
# Epoch 28/100
# 311/311 [==============================] - 45s 143ms/step - loss: 6.8189e-06
# Epoch 29/100
# 311/311 [==============================] - 44s 142ms/step - loss: 6.5945e-06
# Epoch 30/100
# 311/311 [==============================] - 45s 143ms/step - loss: 6.5272e-06
# Epoch 31/100
# 311/311 [==============================] - 45s 143ms/step - loss: 6.4796e-06
# Epoch 32/100
# 311/311 [==============================] - 44s 143ms/step - loss: 6.2996e-06
# Epoch 33/100
# 311/311 [==============================] - 44s 142ms/step - loss: 6.7560e-06
# Epoch 34/100
# 311/311 [==============================] - 45s 143ms/step - loss: 6.3500e-06
# Epoch 35/100
# 311/311 [==============================] - 44s 142ms/step - loss: 6.4149e-06
# Epoch 36/100
# 311/311 [==============================] - 44s 143ms/step - loss: 6.0763e-06
# Epoch 37/100
# 311/311 [==============================] - 44s 143ms/step - loss: 6.1099e-06
# Epoch 38/100
# 311/311 [==============================] - 44s 142ms/step - loss: 6.2667e-06
# Epoch 39/100
# 311/311 [==============================] - 44s 143ms/step - loss: 6.1931e-06
# Epoch 40/100
# 311/311 [==============================] - 44s 142ms/step - loss: 6.0479e-06
# Epoch 41/100
# 311/311 [==============================] - 44s 143ms/step - loss: 5.8446e-06
# Epoch 42/100
# 311/311 [==============================] - 45s 144ms/step - loss: 5.9386e-06
# Epoch 43/100
# 311/311 [==============================] - 45s 143ms/step - loss: 5.5768e-06
# Epoch 44/100
# 311/311 [==============================] - 45s 143ms/step - loss: 5.8758e-06
# Epoch 45/100
# 311/311 [==============================] - 44s 143ms/step - loss: 5.3341e-06
# Epoch 46/100
# 311/311 [==============================] - 44s 142ms/step - loss: 5.9549e-06
# Epoch 47/100
# 311/311 [==============================] - 45s 143ms/step - loss: 6.2107e-06
# Epoch 48/100
# 311/311 [==============================] - 44s 143ms/step - loss: 5.6565e-06
# Epoch 49/100
# 311/311 [==============================] - 44s 143ms/step - loss: 5.3849e-06
# Epoch 50/100
# 311/311 [==============================] - 45s 144ms/step - loss: 5.4541e-06
# Epoch 51/100
# 311/311 [==============================] - 44s 142ms/step - loss: 5.6646e-06
# Epoch 52/100
# 311/311 [==============================] - 44s 142ms/step - loss: 5.4689e-06
# Epoch 53/100
# 311/311 [==============================] - 45s 143ms/step - loss: 5.2322e-06
# Epoch 54/100
# 311/311 [==============================] - 45s 143ms/step - loss: 5.3391e-06
# Epoch 55/100
# 311/311 [==============================] - 45s 144ms/step - loss: 5.5432e-06
# Epoch 56/100
# 311/311 [==============================] - 44s 143ms/step - loss: 5.0269e-061s - loss:
# Epoch 57/100
# 311/311 [==============================] - 44s 142ms/step - loss: 5.3660e-06
# Epoch 58/100
# 311/311 [==============================] - 45s 144ms/step - loss: 5.4613e-06
# Epoch 59/100
# 311/311 [==============================] - 44s 143ms/step - loss: 5.4620e-06
# Epoch 60/100
# 311/311 [==============================] - 44s 143ms/step - loss: 4.9583e-06
# Epoch 61/100
# 311/311 [==============================] - 45s 144ms/step - loss: 5.5450e-06
# Epoch 62/100
# 311/311 [==============================] - 44s 143ms/step - loss: 5.3677e-060s - loss: 5.3677e-0
# Epoch 63/100
# 311/311 [==============================] - 45s 144ms/step - loss: 5.2610e-06
# Epoch 64/100
# 311/311 [==============================] - 45s 143ms/step - loss: 4.9573e-06
# Epoch 65/100
# 311/311 [==============================] - 44s 143ms/step - loss: 5.6214e-06
# Epoch 66/100
# 311/311 [==============================] - 45s 143ms/step - loss: 5.2593e-06
# Epoch 67/100
# 311/311 [==============================] - 44s 143ms/step - loss: 5.4127e-06
# Epoch 68/100
# 311/311 [==============================] - 44s 143ms/step - loss: 5.0939e-06
# Epoch 69/100
# 311/311 [==============================] - 45s 144ms/step - loss: 4.9870e-06
# Epoch 70/100
# 311/311 [==============================] - 44s 143ms/step - loss: 4.5386e-06
# Epoch 71/100
# 311/311 [==============================] - 45s 144ms/step - loss: 5.1064e-06
# Epoch 72/100
# 311/311 [==============================] - 45s 143ms/step - loss: 4.9154e-06
# Epoch 73/100
# 311/311 [==============================] - 45s 143ms/step - loss: 4.9156e-06
# Epoch 74/100
# 311/311 [==============================] - 45s 145ms/step - loss: 4.9040e-06
# Epoch 75/100
# 311/311 [==============================] - 45s 143ms/step - loss: 4.8396e-06
# Epoch 76/100
# 311/311 [==============================] - 45s 144ms/step - loss: 5.2581e-06
# Epoch 77/100
# 311/311 [==============================] - 45s 146ms/step - loss: 4.7721e-06
# Epoch 78/100
# 311/311 [==============================] - 45s 144ms/step - loss: 4.8324e-06
# Epoch 79/100
# 311/311 [==============================] - 45s 144ms/step - loss: 5.4013e-061s - loss
# Epoch 80/100
# 311/311 [==============================] - 46s 148ms/step - loss: 4.8578e-06
# Epoch 81/100
# 311/311 [==============================] - 45s 145ms/step - loss: 5.2194e-06
# Epoch 82/100
# 311/311 [==============================] - 45s 145ms/step - loss: 4.9113e-06
# Epoch 83/100
# 311/311 [==============================] - 45s 144ms/step - loss: 4.7889e-06
# Epoch 84/100
# 311/311 [==============================] - 44s 143ms/step - loss: 4.3852e-06
# Epoch 85/100
# 311/311 [==============================] - 45s 144ms/step - loss: 4.7284e-06
# Epoch 86/100
# 311/311 [==============================] - 45s 144ms/step - loss: 4.7853e-06
# Epoch 87/100
# 311/311 [==============================] - 45s 145ms/step - loss: 4.8688e-06
# Epoch 88/100
# 311/311 [==============================] - 45s 144ms/step - loss: 4.9559e-062s -
# Epoch 89/100
# 311/311 [==============================] - 45s 144ms/step - loss: 4.7623e-06
# Epoch 90/100
# 311/311 [==============================] - 45s 145ms/step - loss: 4.8132e-06
# Epoch 91/100
# 311/311 [==============================] - 45s 143ms/step - loss: 4.8669e-06
# Epoch 92/100
# 311/311 [==============================] - 45s 143ms/step - loss: 4.7676e-06
# Epoch 93/100
# 311/311 [==============================] - 45s 144ms/step - loss: 4.7574e-06
# Epoch 94/100
# 311/311 [==============================] - 44s 143ms/step - loss: 4.9291e-06
# Epoch 95/100
# 311/311 [==============================] - 45s 144ms/step - loss: 4.9001e-06
# Epoch 96/100
# 311/311 [==============================] - 44s 143ms/step - loss: 5.0451e-06
# Epoch 97/100
# 311/311 [==============================] - 44s 143ms/step - loss: 4.7357e-06
# Epoch 98/100
# 311/311 [==============================] - 45s 144ms/step - loss: 4.6051e-06
# Epoch 99/100
# 311/311 [==============================] - 45s 144ms/step - loss: 4.4231e-06
# Epoch 100/100
# 311/311 [==============================] - 45s 143ms/step - loss: 4.7124e-06

# %%
# Prediction

y_pred_3 = regressor.predict(X_train)

# %%
r_lstm1 = r2_score(y_train, y_pred_3)
mse_lstm1 = mean_squared_error(y_train, y_pred_3)
rmse_lstm1 = sqrt(mse_lstm1)
mae_lstm1 = mean_absolute_error(y_train, y_pred_3)

# %%
storeResults1('MS-LSTM',r_lstm1,mse_lstm1,rmse_lstm1,mae_lstm1)

# %%
pred_df = pd.DataFrame({'Actual': y_train, 'Predicted': y_pred_3.flatten()})
pred_df.head()
# Out:
#      Actual  Predicted
# 0  0.007604   0.008753
# 1  0.007535   0.008792
# 2  0.007790   0.008751
# 3  0.007829   0.008912
# 4  0.007893   0.009013

# %%
plt.figure(figsize=(8,8))
plt.ylabel('Close Price', fontsize=16)
plt.plot(pred_df)
plt.legend(['Actual Value', 'Predictions'])
plt.show()

# %% [markdown]
# # MS-SSA-LSTM

# %%
class SSA(keras.optimizers.Optimizer):
    def __init__(self, learning_rate=0.001, momentum=0.9, name="SSA", **kwargs):
        """Call super().__init__() and use _set_hyper() to store hyperparameters"""
        super().__init__(name, **kwargs)
        self._set_hyper("learning_rate", kwargs.get("lr", learning_rate)) # handle lr=learning_rate
        self._set_hyper("decay", self._initial_decay) # 
        self._set_hyper("momentum", momentum)
    
    def _create_slots(self, var_list):
        """For each model variable, create the optimizer variable associated with it.
        TensorFlow calls these optimizer variables "slots".
        For momentum optimization, we need one momentum slot per model variable.
        """
        for var in var_list:
            self.add_slot(var, "momentum")

    @tf.function
    def _resource_apply_dense(self, grad, var):
        """Update the slots and perform one optimization step for one model variable
        """
        var_dtype = var.dtype.base_dtype
        lr_t = self._decayed_lr(var_dtype) # handle learning rate decay
        momentum_var = self.get_slot(var, "momentum")
        momentum_hyper = self._get_hyper("momentum", var_dtype)
        momentum_var.assign(momentum_var * momentum_hyper - (1. - momentum_hyper)* grad)
        var.assign_add(momentum_var * lr_t)

    def _resource_apply_sparse(self, grad, var):
        raise NotImplementedError

    def get_config(self):
        base_config = super().get_config()
        return {
            **base_config,
            "learning_rate": self._serialize_hyperparameter("learning_rate"),
            "decay": self._serialize_hyperparameter("decay"),
            "momentum": self._serialize_hyperparameter("momentum"),
        }

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
optimizer=SSA()

# %%
# Initialising the RNN
regressor = Sequential()
# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
regressor.compile(optimizer = optimizer, loss = 'mean_squared_error')

# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 311/311 [==============================] - 56s 148ms/step - loss: 5.9519e-05
# Epoch 2/100
# 311/311 [==============================] - 46s 148ms/step - loss: 2.2271e-05
# Epoch 3/100
# 311/311 [==============================] - 46s 149ms/step - loss: 1.7832e-05
# Epoch 4/100
# 311/311 [==============================] - 46s 148ms/step - loss: 1.5138e-05
# Epoch 5/100
# 311/311 [==============================] - 46s 150ms/step - loss: 1.2989e-05
# Epoch 6/100
# 311/311 [==============================] - 46s 148ms/step - loss: 1.1539e-05
# Epoch 7/100
# 311/311 [==============================] - 47s 150ms/step - loss: 1.1687e-05
# Epoch 8/100
# 311/311 [==============================] - 46s 149ms/step - loss: 1.0762e-05
# Epoch 9/100
# 311/311 [==============================] - 46s 149ms/step - loss: 1.0190e-05
# Epoch 10/100
# 311/311 [==============================] - 46s 148ms/step - loss: 1.0095e-05
# Epoch 11/100
# 311/311 [==============================] - 47s 150ms/step - loss: 9.3472e-06
# Epoch 12/100
# 311/311 [==============================] - 46s 149ms/step - loss: 9.2819e-06
# Epoch 13/100
# 311/311 [==============================] - 46s 149ms/step - loss: 8.9152e-06
# Epoch 14/100
# 311/311 [==============================] - 47s 151ms/step - loss: 8.7623e-06
# Epoch 15/100
# 311/311 [==============================] - 46s 148ms/step - loss: 8.4661e-06
# Epoch 16/100
# 311/311 [==============================] - 47s 150ms/step - loss: 8.4896e-06
# Epoch 17/100
# 311/311 [==============================] - 46s 150ms/step - loss: 8.2519e-06
# Epoch 18/100
# 311/311 [==============================] - 47s 150ms/step - loss: 7.6944e-06
# Epoch 19/100
# 311/311 [==============================] - 47s 150ms/step - loss: 7.8747e-06
# Epoch 20/100
# 311/311 [==============================] - 46s 149ms/step - loss: 8.5037e-06
# Epoch 21/100
# 311/311 [==============================] - 47s 150ms/step - loss: 7.5321e-06
# Epoch 22/100
# 311/311 [==============================] - 47s 150ms/step - loss: 7.0604e-06
# Epoch 23/100
# 311/311 [==============================] - 46s 149ms/step - loss: 7.3528e-06
# Epoch 24/100
# 311/311 [==============================] - 47s 150ms/step - loss: 6.9646e-06
# Epoch 25/100
# 311/311 [==============================] - 46s 149ms/step - loss: 7.2637e-06
# Epoch 26/100
# 311/311 [==============================] - 47s 150ms/step - loss: 6.4351e-06
# Epoch 27/100
# 311/311 [==============================] - 46s 149ms/step - loss: 6.8346e-06
# Epoch 28/100
# 311/311 [==============================] - 46s 149ms/step - loss: 6.9219e-06
# Epoch 29/100
# 311/311 [==============================] - 48s 153ms/step - loss: 6.7520e-06
# Epoch 30/100
# 311/311 [==============================] - 46s 149ms/step - loss: 6.4981e-06
# Epoch 31/100
# 311/311 [==============================] - 46s 149ms/step - loss: 6.5653e-06
# Epoch 32/100
# 311/311 [==============================] - 47s 150ms/step - loss: 6.2720e-06
# Epoch 33/100
# 311/311 [==============================] - 46s 148ms/step - loss: 6.7825e-06
# Epoch 34/100
# 311/311 [==============================] - 47s 150ms/step - loss: 6.3757e-06
# Epoch 35/100
# 311/311 [==============================] - 46s 149ms/step - loss: 6.6675e-06
# Epoch 36/100
# 311/311 [==============================] - 46s 149ms/step - loss: 6.2639e-06
# Epoch 37/100
# 311/311 [==============================] - 46s 148ms/step - loss: 6.2512e-06
# Epoch 38/100
# 311/311 [==============================] - 46s 149ms/step - loss: 6.4554e-06
# Epoch 39/100
# 311/311 [==============================] - 47s 150ms/step - loss: 6.3392e-06
# Epoch 40/100
# 311/311 [==============================] - 46s 148ms/step - loss: 6.1465e-06
# Epoch 41/100
# 311/311 [==============================] - 46s 149ms/step - loss: 6.0459e-06
# Epoch 42/100
# 311/311 [==============================] - 46s 149ms/step - loss: 6.0224e-06
# Epoch 43/100
# 311/311 [==============================] - 46s 149ms/step - loss: 5.7791e-061s - lo
# Epoch 44/100
# 311/311 [==============================] - 47s 150ms/step - loss: 6.1820e-06
# Epoch 45/100
# 311/311 [==============================] - 46s 149ms/step - loss: 5.5681e-06
# Epoch 46/100
# 311/311 [==============================] - 47s 150ms/step - loss: 6.0927e-06
# Epoch 47/100
# 311/311 [==============================] - 46s 149ms/step - loss: 6.3049e-06
# Epoch 48/100
# 311/311 [==============================] - 47s 150ms/step - loss: 5.8740e-06
# Epoch 49/100
# 311/311 [==============================] - 46s 149ms/step - loss: 5.4285e-06
# Epoch 50/100
# 311/311 [==============================] - 46s 149ms/step - loss: 5.5066e-06
# Epoch 51/100
# 311/311 [==============================] - 47s 150ms/step - loss: 5.8850e-06
# Epoch 52/100
# 311/311 [==============================] - 46s 147ms/step - loss: 5.5383e-06
# Epoch 53/100
# 311/311 [==============================] - 45s 145ms/step - loss: 5.3442e-06
# Epoch 54/100
# 311/311 [==============================] - 45s 146ms/step - loss: 5.5344e-06
# Epoch 55/100
# 311/311 [==============================] - 46s 147ms/step - loss: 5.6612e-06
# Epoch 56/100
# 311/311 [==============================] - 46s 147ms/step - loss: 5.1790e-06
# Epoch 57/100
# 311/311 [==============================] - 46s 148ms/step - loss: 5.6488e-06
# Epoch 58/100
# 311/311 [==============================] - 45s 146ms/step - loss: 5.7335e-06
# Epoch 59/100
# 311/311 [==============================] - 46s 147ms/step - loss: 5.5837e-06
# Epoch 60/100
# 311/311 [==============================] - 46s 146ms/step - loss: 5.0389e-06
# Epoch 61/100
# 311/311 [==============================] - 45s 146ms/step - loss: 5.9335e-06
# Epoch 62/100
# 311/311 [==============================] - 46s 147ms/step - loss: 5.7167e-06
# Epoch 63/100
# 311/311 [==============================] - 45s 146ms/step - loss: 5.4047e-06
# Epoch 64/100
# 311/311 [==============================] - 45s 146ms/step - loss: 4.9910e-06
# Epoch 65/100
# 311/311 [==============================] - 46s 147ms/step - loss: 5.7186e-06
# Epoch 66/100
# 311/311 [==============================] - 45s 145ms/step - loss: 5.4213e-06
# Epoch 67/100
# 311/311 [==============================] - 46s 148ms/step - loss: 5.3962e-06
# Epoch 68/100
# 311/311 [==============================] - 46s 147ms/step - loss: 5.1592e-06
# Epoch 69/100
# 311/311 [==============================] - 45s 146ms/step - loss: 5.1358e-06
# Epoch 70/100
# 311/311 [==============================] - 46s 147ms/step - loss: 4.6732e-06
# Epoch 71/100
# 311/311 [==============================] - 45s 146ms/step - loss: 5.0060e-06
# Epoch 72/100
# 311/311 [==============================] - 45s 146ms/step - loss: 5.0887e-06
# Epoch 73/100
# 311/311 [==============================] - 46s 147ms/step - loss: 5.0880e-06
# Epoch 74/100
# 311/311 [==============================] - 45s 146ms/step - loss: 5.0029e-06
# Epoch 75/100
# 311/311 [==============================] - 45s 146ms/step - loss: 5.0484e-06
# Epoch 76/100
# 311/311 [==============================] - 46s 148ms/step - loss: 5.3264e-06
# Epoch 77/100
# 311/311 [==============================] - 46s 147ms/step - loss: 4.9730e-06
# Epoch 78/100
# 311/311 [==============================] - 46s 147ms/step - loss: 5.0568e-06
# Epoch 79/100
# 311/311 [==============================] - 46s 146ms/step - loss: 5.4562e-06
# Epoch 80/100
# 311/311 [==============================] - 45s 145ms/step - loss: 4.9621e-06
# Epoch 81/100
# 311/311 [==============================] - 46s 147ms/step - loss: 5.3442e-06
# Epoch 82/100
# 311/311 [==============================] - 45s 146ms/step - loss: 4.9798e-06
# Epoch 83/100
# 311/311 [==============================] - 46s 146ms/step - loss: 4.8689e-06
# Epoch 84/100
# 311/311 [==============================] - 46s 147ms/step - loss: 4.4113e-06
# Epoch 85/100
# 311/311 [==============================] - 45s 146ms/step - loss: 4.8250e-06
# Epoch 86/100
# 311/311 [==============================] - 46s 147ms/step - loss: 4.8366e-06
# Epoch 87/100
# 311/311 [==============================] - 45s 146ms/step - loss: 4.7911e-06
# Epoch 88/100
# 311/311 [==============================] - 45s 146ms/step - loss: 5.0483e-06
# Epoch 89/100
# 311/311 [==============================] - 46s 147ms/step - loss: 4.8270e-06
# Epoch 90/100
# 311/311 [==============================] - 46s 146ms/step - loss: 4.7219e-06
# Epoch 91/100
# 311/311 [==============================] - 45s 146ms/step - loss: 5.0390e-06
# Epoch 92/100
# 311/311 [==============================] - 45s 146ms/step - loss: 4.7229e-06
# Epoch 93/100
# 311/311 [==============================] - 45s 145ms/step - loss: 4.7644e-06
# Epoch 94/100
# 311/311 [==============================] - 45s 145ms/step - loss: 4.9560e-06
# Epoch 95/100
# 311/311 [==============================] - 45s 145ms/step - loss: 4.8597e-06
# Epoch 96/100
# 311/311 [==============================] - 45s 145ms/step - loss: 5.0361e-06
# Epoch 97/100
# 311/311 [==============================] - 46s 146ms/step - loss: 4.7263e-06
# Epoch 98/100
# 311/311 [==============================] - 45s 145ms/step - loss: 4.7378e-06
# Epoch 99/100
# 311/311 [==============================] - 45s 146ms/step - loss: 4.4659e-06
# Epoch 100/100
# 311/311 [==============================] - 45s 145ms/step - loss: 4.8316e-06

# %%
# Prediction

y_pred_3 = regressor.predict(X_train)

# %%
r_lstm3 = r2_score(y_train, y_pred_3)
mse_lstm3 = mean_squared_error(y_train, y_pred_3)
rmse_lstm3 = sqrt(mse_lstm3)
mae_lstm3 = mean_absolute_error(y_train, y_pred_3)

# %%
storeResults1('MS-SSA-LSTM',r_lstm3,mse_lstm3,rmse_lstm3,mae_lstm3)

# %%
pred_df = pd.DataFrame({'Actual': y_train, 'Predicted': y_pred_3.flatten()})
pred_df.head()
# Out:
#      Actual  Predicted
# 0  0.007604   0.008522
# 1  0.007535   0.008561
# 2  0.007790   0.008521
# 3  0.007829   0.008686
# 4  0.007893   0.008773

# %%
plt.figure(figsize=(8,8))
plt.ylabel('Close Price', fontsize=16)
plt.plot(pred_df)
plt.legend(['Actual Value', 'Predictions'])
plt.show()

# %% [markdown]
# # Comparison

# %% [markdown]
# # Stock Sentiment

# %%
#creating dataframe
result = pd.DataFrame({ 'ML Model' : ML_Model,
                        'Accuracy' : accuracy,
                        'Precision': precision,
                        'Recall'   : recall,
                        'F1-Score': f1score
                      })

# %%
result
# Out:
#             ML Model  Accuracy  Precision  Recall  F1-Score
# 0                MLP     0.771      0.770   0.771     0.771
# 1            XGBoost     0.784      0.777   0.784     0.782
# 2  Voting CLassifier     0.803      0.819   0.803     0.808
# 3                CNN     0.773      0.774   0.773     0.761
# 4               LSTM     1.000      1.000   1.000     1.000
# 5            MS-LSTM     0.998      0.998   0.998     0.998
# 6        MS-SSA-LSTM     1.000      1.000   1.000     1.000
# 7           LSTM-GRU     1.000      1.000   1.000     1.000

# %% [markdown]
# # Graph

# %%
classifier = ML_Model
y_pos = np.arange(len(classifier))

# %% [markdown]
# # Accuracy

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, accuracy, align='center', alpha=0.5,color='blue')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Accuracy Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # Precision

# %%
plt2.barh(y_pos, precision, align='center', alpha=0.5,color='red')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Precision Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # Recall

# %%
plt2.barh(y_pos, recall, align='center', alpha=0.5,color='cyan')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Recall Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # F1 Score

# %%
plt2.barh(y_pos, f1score, align='center', alpha=0.5,color='magenta')
plt2.yticks(y_pos, classifier)
plt2.xlabel('F1 Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # Stock Price

# %%
#creating dataframe
result = pd.DataFrame({ 'ML Model' : ML_Model1,
                        'R2 Score' : r2,
                        'MSE': mse,
                        'RMSE'   : rmse,
                        'MAE': mae
                      })

# %%
result
# Out:
#            ML Model  R2 Score    MSE   RMSE    MAE
# 0               MLP     0.987  0.001  0.030  0.023
# 1           XGBoost     0.999  0.000  1.220  1.220
# 2  Voting Regressor     0.999  0.000  0.010  0.006
# 3               CNN     0.996  0.000  0.010  0.011
# 4              LSTM     0.992  0.001  0.024  0.017
# 5           MS-LSTM     0.995  0.000  0.001  0.001
# 6       MS-SSA-LSTM     0.994  0.000  0.001  0.001

# %%
classifier = ML_Model1
y_pos = np.arange(len(classifier))

# %% [markdown]
# # R2 Score

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, r2, align='center', alpha=0.5,color='blue')
plt2.yticks(y_pos, classifier)
plt2.xlabel('R2 Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # MSE

# %%
plt2.barh(y_pos, mse, align='center', alpha=0.5,color='red')
plt2.yticks(y_pos, classifier)
plt2.xlabel('MSE')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # RMSE

# %%
plt2.barh(y_pos, rmse, align='center', alpha=0.5,color='cyan')
plt2.yticks(y_pos, classifier)
plt2.xlabel('RMSE')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # MAE

# %%
plt2.barh(y_pos, mae, align='center', alpha=0.5,color='magenta')
plt2.yticks(y_pos, classifier)
plt2.xlabel('MAE')
plt2.title('Classification Performance')
plt2.show()
